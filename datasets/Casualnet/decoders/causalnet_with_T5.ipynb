# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import json
import random
import re
import torch

# Initialize the tokenizer and model
device = "cuda" if torch.cuda.is_available() else "cpu"
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-xxl")
model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-xxl")
run = 2
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/674 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/53.0k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/9.45G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/9.60G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/9.96G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/10.0G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/6.06G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
# # Load the COPA data from a JSONL file
# def load_copa_data(file_path):
#     with open(file_path, 'r') as file:
#         return [json.loads(line) for line in file]

# Function to load the dataset from a JSON file
def load_copa_data(file_path, sample_size=100000):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)

    if sample_size >= len(data):
        return data

    return random.sample(data, sample_size)

# Format the COPA query for the T5 model
def format_copa_query(item):
    premise = item['context']
    hypothesis1 = item['choice_id: 0']
    hypothesis2 = item['choice_id: 1']
    hypothesis3 = item['choice_id: 2']
    ask_for = item['ask-for']
    task = "cause" if ask_for == "cause" else "effect"
    return f"Given the premise: {premise}; what is the {task}? Is it hypothesis 1: {hypothesis1}; OR hypothesis 2: {hypothesis2}; OR hypothesis 3: {hypothesis3}?"

# Send the query to the T5 model and get the response
def query_t5(query):
    inputs = tokenizer.encode(query, return_tensors="pt")
    outputs = model.generate(inputs, max_length=40, num_beams=4, early_stopping=True)
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response



def normalize_text(text):
    """Normalize text by removing punctuation, converting to lowercase, and trimming spaces."""
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    return text.strip()

saved_responses = []
def is_response_correct(response, item):
    correct_hypothesis = item['choice_id: ' + str(item['label'])]
    response_text = normalize_text(response)
    correct_hypothesis_normalized = normalize_text(correct_hypothesis)

    saved_responses.append({
            'index': item['index'],
            'premise': item['context'],
            'task': item['ask-for'],
            'hypothesis1': item['choice_id: 0'],
            'hypothesis2': item['choice_id: 1'],
            'hypothesis3': item['choice_id: 2'],
            'label': item['label'],
            'generated_response': response_text
        })

    # Direct comparison for exact matches after normalization
    if response_text == correct_hypothesis_normalized:
        return True

    # Handling direct references to "hypothesis 1" or "hypothesis 2"
    if "hypothesis 1" in response_text or "hypothesis 2" in response_text or "hypothesis 3" in response_text:
        if "hypothesis 1" in response_text:
            hypothesis_number = 1
        elif"hypothesis 2" in response_text:
            hypothesis_number = 2
        else:
            hypothesis_number = 3
        correct_hypothesis_number = item['label'] + 1
        return hypothesis_number == correct_hypothesis_number

    # Calculate match ratio for a more nuanced comparison
    key_phrases = correct_hypothesis_normalized.split()
    matching_phrases = [phrase for phrase in key_phrases if phrase in response_text]
    match_ratio = len(matching_phrases) / len(key_phrases)

    # Consider a response correct if a significant portion of key phrases match
    return match_ratio > 0.5  # Adjust this threshold based on experimentation and desired strictness


def compute_metrics(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average='weighted')
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    return [accuracy, f1, precision, recall]

responses_file = '/content/drive/MyDrive/Datasets/causalnet_t5_responses_' + str(run) + '.jsonl'

def evaluate_accuracy(data):
    correct_count = 0
    total_items = len(data)

    try:
        # If model has already been run
        with open(responses_file, 'r', encoding='utf-8') as file:
            saved_responses = [json.loads(line) for line in file]
        print("Loaded saved responses.")
    except FileNotFoundError:
        for index, item in enumerate(data):
            query = format_copa_query(item)
            print(f"\nProcessing item {index + 1}/{total_items}...")

            response = query_t5(query)
            print(f"Generated Response: {response}")
            acts.append(item['label'])

            correct_hypothesis = item['choice_id: ' + str(item['label'])]
            print(f"Correct Hypothesis: hypothesis {item['label'] + 1}, {correct_hypothesis}")

            is_correct = is_response_correct(response, item)

            if is_correct:
                print(f"Item {index + 1}: Correct")
                correct_count += 1
                preds.append(item['label'])
            else:
                print(f"Item {index + 1}: Incorrect")
                preds.append(0 if item['label'] else 1)

        accuracy = correct_count / total_items
        print(f"\nAccuracy: {accuracy * 100:.2f}%")
        return accuracy


# def is_response_correct_loaded(item, response):
#     try:
#         pred_hyp = int(response.split(' ')[-1])
#     except ValueError:
#         pred_hyp = -1
#     return pred_hyp == item['label'] + 1

# Load the COPA data
copa_data = load_copa_data('/content/drive/MyDrive/Datasets/causalnetcd.json')

# Evaluate accuracy
# If model has already been run
# with open(responses_file, 'r', encoding='utf-8') as file:
#     saved_responses = [json.loads(line) for line in file]
# print("Loaded saved responses.")
# preds, golds = [], []
# for item in saved_responses:
#     if is_response_correct_loaded(item, item['generated_response']):
#         preds.append(item['label'])
#     else:
#         preds.append(1 - item['label'])  # Assuming binary labels (0 and 1)
#     golds.append(item['label'])

# sklearn_accuracy, f1val, precisionval, recallval = compute_metrics(golds, preds)
# print(f"sklearn Accuracy: {sklearn_accuracy * 100:.3f}%")
# print(f"F1: {f1val * 100:.3f}%")
# print(f"Precision: {precisionval * 100:.3f}%")
# print(f"Recall: {recallval * 100:.3f}%")
# End if model has already been run

saved_responses = []
acts, preds = [], []  # acts: ground truth
accuracy = evaluate_accuracy(copa_data)

sklearn_accuracy, f1val, precisionval, recallval = compute_metrics(acts, preds)
print(f"Accuracy: {accuracy * 100:.3f}%")
print(f"sklearn Accuracy: {sklearn_accuracy * 100:.3f}%")
print(f"F1: {f1val * 100:.3f}%")
print(f"Precision: {precisionval * 100:.3f}%")
print(f"Recall: {recallval * 100:.3f}%")

with open(responses_file, 'w', encoding='utf-8') as file:
        for response in saved_responses:
            file.write(json.dumps(response) + '\n')
print('Responses saved')
# Out:
# Processing item 1/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The celebrity's influence changed teenagers' perceptions more significantly than expected.
# Item 1: Correct
#
# Processing item 2/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The road improved access to educational resources and opportunities.
# Item 2: Correct
#
# Processing item 3/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Improved agricultural efficiency made rural living more sustainable, reducing the need for urban migration.
# Item 3: Correct
#
# Processing item 4/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The rise in public transportation usage reduced the number of cars on the road.
# Item 4: Correct
#
# Processing item 5/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The jellyfish blooms could have deterred tourists despite the beach's accolades.
# Item 5: Correct
#
# Processing item 6/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, The recycling program might have inadvertently encouraged more consumption, leading to more waste.
# Item 6: Correct
#
# Processing item 7/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The financial security provided by UBI encouraged entrepreneurial ventures.
# Item 7: Correct
#
# Processing item 8/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The increase in green spaces indirectly reduced pollution by promoting a cleaner urban environment.
# Item 8: Correct
#
# Processing item 9/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Renewable energy projects created new job opportunities, contributing to lower unemployment.
# Item 9: Correct
#
# Processing item 10/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The increase in tourism led to greater awareness and compliance with fishing regulations.
# Item 10: Correct
#
# Processing item 11/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The reduction in plastic waste improved natural habitats, indirectly benefiting wildlife.
# Item 11: Correct
#
# Processing item 12/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The availability of online learning platforms provided alternative education pathways.
# Item 12: Correct
#
# Processing item 13/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The ban on diesel vehicles directly contributed to cleaner air, while the other factors played a supportive role.
# Item 13: Correct
#
# Processing item 14/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The new tax law created a more favorable environment for small businesses, encouraging entrepreneurship.
# Item 14: Correct
#
# Processing item 15/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, Popular science fiction movies and virtual reality technology made STEM subjects more appealing to young minds.
# Item 15: Correct
#
# Processing item 16/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The 'green roof' policy created more natural cooling areas, contributing to the reduction of heat islands.
# Item 16: Correct
#
# Processing item 17/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, Organic farming practices led to healthier diets, contributing to longer life expectancy.
# Item 17: Correct
#
# Processing item 18/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The enhancement of public libraries created spaces that fostered community interaction and learning.
# Item 18: Correct
#
# Processing item 19/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, The increase in bicycle usage reduced reliance on motor vehicles, contributing to lower pollution levels.
# Item 19: Correct
#
# Processing item 20/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The digital literacy program empowered more citizens to engage in tech entrepreneurship.
# Item 20: Correct
#
# Processing item 21/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, Public art projects provided a constructive outlet for youth, contributing to lower crime rates.
# Item 21: Correct
#
# Processing item 22/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Advancements in battery technology made renewable energy sources more viable, reducing reliance on fossil fuels.
# Item 22: Correct
#
# Processing item 23/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Free Wi-Fi in public areas attracted more entrepreneurs and tourists, boosting local business growth.
# Item 23: Correct
#
# Processing item 24/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, Investment in nuclear energy led to reduced reliance on coal, thereby improving air quality.
# Item 24: Correct
#
# Processing item 25/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, Mandatory coding classes equipped youth with the skills to participate in the burgeoning global tech industry.
# Item 25: Correct
#
# Processing item 26/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The increase in urban green spaces provided residents with a natural, calming environment, contributing to stress reduction.
# Item 26: Correct
#
# Processing item 27/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The ban on plastic bags significantly reduced marine pollution, indirectly benefiting marine biodiversity.
# Item 27: Correct
#
# Processing item 28/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The public health campaign effectively raised awareness about the dangers of smoking, leading to a decline in smoking rates.
# Item 28: Correct
#
# Processing item 29/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, High-speed internet access enabled residents to participate more actively in the global e-commerce trend.
# Item 29: Correct
#
# Processing item 30/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The new public transport system provided an effective alternative to car use, easing traffic congestion.
# Item 30: Correct
#
# Processing item 31/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The increase in minimum wage provided employees with more financial security, leading to lower turnover.
# Item 31: Correct
#
# Processing item 32/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, Advancements in solar panel technology made renewable energy more cost-effective.
# Item 32: Correct
#
# Processing item 33/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, Advancements in mobile technology made telemedicine more accessible in rural areas.
# Item 33: Correct
#
# Processing item 34/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The rise in e-cigarette popularity offered an alternative to traditional smoking, contributing to the decrease.
# Item 34: Correct
#
# Processing item 35/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, Advancements in energy-saving technologies complemented the green building standards, enhancing overall energy efficiency.
# Item 35: Correct
#
# Processing item 36/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, The decrease in urban pollution contributed to a healthier environment, indirectly affecting community wellbeing.
# Item 36: Correct
#
# Processing item 37/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The global trend towards digitalization created a conducive environment for innovation, complementing the focus on STEM education.
# Item 37: Correct
#
# Processing item 38/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The growth of urban green spaces provided a more peaceful and healthy living environment, contributing to quality of life.
# Item 38: Correct
#
# Processing item 39/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, Improvements in electric vehicle technology made them more accessible, contributing to reduced pollution.
# Item 39: Correct
#
# Processing item 40/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Advancements in internet technology made online learning more accessible and appealing.
# Item 40: Correct
#
# Processing item 41/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Stricter traffic laws led to more cautious driving behaviors, contributing to fewer accidents.
# Item 41: Correct
#
# Processing item 42/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, Advancements in wind and solar technology made renewable energy more feasible and efficient.
# Item 42: Correct
#
# Processing item 43/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, New educational technologies made learning more accessible and engaging, contributing to higher literacy rates.
# Item 43: Correct
#
# Processing item 44/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, Advancements in weather forecasting technology allowed for better preparation and response to potential flooding.
# Item 44: Correct
#
# Processing item 45/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Improvements in public transportation offered a cleaner alternative to private car use, aiding in emission reduction.
# Item 45: Correct
#
# Processing item 46/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, Advancements in energy storage technologies made renewable energy sources like solar more reliable, contributing to increased production.
# Item 46: Correct
#
# Processing item 47/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Sustainable farming practices increased the efficiency and sustainability of food production, contributing to food security.
# Item 47: Correct
#
# Processing item 48/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 2, Stricter waste management regulations effectively reduced the amount of litter and pollution in the city.
# Item 48: Incorrect
#
# Processing item 49/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The rise in internet connectivity made e-commerce more accessible to rural populations, contributing to its growth.
# Item 49: Correct
#
# Processing item 50/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, New policy promoting neighborhood initiatives encouraged residents to participate more in local activities, including urban gardening.
# Item 50: Correct
#
# Processing item 51/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, Increased public awareness about water conservation led to more mindful usage, augmenting the effect of the water-saving devices.
# Item 51: Correct
#
# Processing item 52/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, Global environmental agreements raised awareness and created a conducive environment for green technology innovation.
# Item 52: Correct
#
# Processing item 53/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Technological advancements in solar panels made them more efficient and cost-effective, contributing to lower energy costs.
# Item 53: Correct
#
# Processing item 54/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The increase in electric vehicle usage led to changes in driving patterns, complementing the smart traffic management systems.
# Item 54: Correct
#
# Processing item 55/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, Advancements in medical technology provided more effective treatment options, contributing to better health outcomes.
# Item 55: Correct
#
# Processing item 56/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The growth in urban tree planting provided natural cooling, which along with green roofing, helped reduce heat islands.
# Item 56: Correct
#
# Processing item 57/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Improvements in internet infrastructure made online filing more accessible, contributing to its efficiency.
# Item 57: Correct
#
# Processing item 58/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The trend towards healthier eating habits contributed to improved overall public health.
# Item 58: Correct
#
# Processing item 59/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The rise in entrepreneurship education provided the necessary skills and knowledge, fueling small business growth.
# Item 59: Correct
#
# Processing item 60/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The increase in community environmental awareness led to more responsible waste management practices, reducing landfill waste.
# Item 60: Correct
#
# Processing item 61/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The reduction in the use of private vehicles led to lower emissions, complementing the effect of electric buses.
# Item 61: Correct
#
# Processing item 62/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Healthy eating programs provided better nutritional education, contributing to lower obesity rates.
# Item 62: Correct
#
# Processing item 63/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The city-wide campaign effectively promoted local tourism, attracting more visitors.
# Item 63: Correct
#
# Processing item 64/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The increase in telemedicine services provided remote access to healthcare, complementing the physical healthcare facilities.
# Item 64: Correct
#
# Processing item 65/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, The rise in neighborhood associations fostered a stronger sense of community, encouraging more engagement.
# Item 65: Correct
#
# Processing item 66/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The rise in energy conservation awareness led to more mindful energy usage by residents, complementing the impact of energy-efficient appliances.
# Item 66: Correct
#
# Processing item 67/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Advancements in renewable energy technology made it more efficient and cost-effective, encouraging the shift from fossil fuels.
# Item 67: Correct
#
# Processing item 68/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The increase in electric vehicle usage contributed to lower emissions, aiding in the reduction of air pollution.
# Item 68: Correct
#
# Processing item 69/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Improvements in dietary habits contributed to better overall health, complementing the availability of sports facilities.
# Item 69: Correct
#
# Processing item 70/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The decrease in vehicle emissions played a significant role in reducing air pollutants, aiding the impact of the tree planting initiative.
# Item 70: Correct
#
# Processing item 71/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Improvements in bike technology made cycling more appealing and accessible, contributing to its popularity.
# Item 71: Correct
#
# Processing item 72/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The global trend in digital transformation created a conducive environment for online business growth.
# Item 72: Correct
#
# Processing item 73/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, Advancements in water recycling technology increased the efficiency of water use, contributing to the reduction in scarcity.
# Item 73: Correct
#
# Processing item 74/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Enhancements to cultural attractions drew more visitors, complementing the impact of the public art initiative.
# Item 74: Correct
#
# Processing item 75/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The park beautification projects made the parks more attractive, encouraging more visitors.
# Item 75: Correct
#
# Processing item 76/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 2, Private sector funding provided additional resources, boosting research and innovation.
# Item 76: Incorrect
#
# Processing item 77/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, Improvements in waste management systems effectively reduced the amount of waste reaching marine environments.
# Item 77: Correct
#
# Processing item 78/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, Community safety initiatives fostered a safer environment, complementing the impact of smart street lighting.
# Item 78: Correct
#
# Processing item 79/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, Community-led health initiatives encouraged more communal activities and interactions, fostering cohesion.
# Item 79: Correct
#
# Processing item 80/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, International collaboration in health science led to the sharing of knowledge and best practices, enhancing healthcare quality.
# Item 80: Correct
#
# Processing item 81/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, Noise reduction policies created a more serene urban environment, contributing to lower stress levels.
# Item 81: Correct
#
# Processing item 82/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, Advancements in energy storage technologies increased the efficiency and reduced the cost of renewable energy.
# Item 82: Correct
#
# Processing item 83/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The marketing campaign effectively attracted tourists by highlighting the town's unique cultural attractions.
# Item 83: Correct
#
# Processing item 84/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The growth in online educational resources provided accessible learning opportunities, enhancing digital literacy.
# Item 84: Correct
#
# Processing item 85/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, Sustainable farming practices increased the availability of local, healthy food options, enhancing food security.
# Item 85: Correct
#
# Processing item 86/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 2, Advancements in weather forecasting technology allowed for better preparation and response to potential flooding, reducing damages.
# Item 86: Incorrect
#
# Processing item 87/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, Advancements in renewable energy technology made green energy projects more viable and efficient.
# Item 87: Correct
#
# Processing item 88/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The trend towards remote working reduced the number of vehicles on the road, aiding in easing traffic conditions.
# Item 88: Correct
#
# Processing item 89/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, The rise in digital literacy enabled citizens to better engage with digital services, improving overall efficiency.
# Item 89: Correct
#
# Processing item 90/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The increase in recycling facilities provided more options for waste disposal, contributing to less littering.
# Item 90: Correct
#
# Processing item 91/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The introduction of solar-powered public lighting provided an additional sustainable energy source, enhancing the town's lighting efficiency.
# Item 91: Correct
#
# Processing item 92/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, Advancements in water-saving technologies enhanced the efficiency of water use, complementing the impact of the conservation laws.
# Item 92: Correct
#
# Processing item 93/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, Advancements in eco-friendly building materials made sustainable construction more feasible and attractive.
# Item 93: Correct
#
# Processing item 94/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, The trend towards digital transformation enabled more businesses to adapt to e-commerce and remote working models.
# Item 94: Correct
#
# Processing item 95/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The trend towards healthier eating habits contributed to better overall health, reducing health issues.
# Item 95: Correct
#
# Processing item 96/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: hypothesis 3, The growth in local artisan businesses showcased the city's unique culture, attracting tourists and boosting local pride.
# Item 96: Correct
#
# Processing item 97/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, Advancements in green technology made solar panels and wind turbines more efficient and cost-effective.
# Item 97: Correct
#
# Processing item 98/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: hypothesis 2, The trend towards sustainable urban planning led to more green spaces and less congestion, enhancing livability.
# Item 98: Correct
#
# Processing item 99/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: hypothesis 1, The increase in fitness facilities provided more opportunities for regular exercise, contributing to better public health.
# Item 99: Correct
#
# Processing item 100/1000...

# %%
from google.colab import runtime
runtime.unassign()
