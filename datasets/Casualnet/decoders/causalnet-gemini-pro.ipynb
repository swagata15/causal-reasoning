# %%
# !pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Requirement already satisfied: google-ai-generativelanguage==0.4.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (0.4.0)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.27.0)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.11.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.9.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (3.20.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.66.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.4.0->google-generativeai) (1.23.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.62.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth->google-generativeai) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth->google-generativeai) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth->google-generativeai) (4.9)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.60.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.48.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth->google-generativeai) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2024.2.2)

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Configure Gemini API
from google.colab import userdata
GOOGLE_API_KEY = userdata.get('gemini')
genai.configure(api_key=GOOGLE_API_KEY)
gemini_model = genai.GenerativeModel('gemini-pro')

# %%
run = 1

# %%
import json
import re
import google.generativeai as genai

saved_responses = []

# Function to normalize text for comparison
def normalize_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    return text.strip()

# Function to determine if the response is correct
def is_response_correct(response, item):
    correct_hypothesis = item['choice_id: ' + str(item['label'])]
    response_text = normalize_text(response)
    correct_hypothesis_normalized = normalize_text(correct_hypothesis)

    saved_responses.append({
            'index': item['index'],
            'premise': item['context'],
            'task': item['ask-for'],
            'hypothesis1': item['choice_id: 0'],
            'hypothesis2': item['choice_id: 1'],
            'hypothesis3': item['choice_id: 2'],
            'label': item['label'],
            'generated_response': response_text
        })

    if response_text == correct_hypothesis_normalized:
        return True

    if "hypothesis 1" in response_text or "hypothesis 2" in response_text or "hypothesis 3" in response_text:
        if "hypothesis 1" in response_text:
            hypothesis_number = 1
        elif"hypothesis 2" in response_text:
            hypothesis_number = 2
        else:
            hypothesis_number = 3
        correct_hypothesis_number = item['label'] + 1
        return hypothesis_number == correct_hypothesis_number

    key_phrases = correct_hypothesis_normalized.split()
    matching_phrases = [phrase for phrase in key_phrases if phrase in response_text]
    match_ratio = len(matching_phrases) / len(key_phrases)

    return match_ratio > 0.5

# Function to load the dataset from a JSON file
def load_copa_data(file_path, sample_size=100000):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)

    if sample_size >= len(data):
        return data

    return random.sample(data, sample_size)

def format_copa_query_for_gemini(item):
    premise = item['context']
    hypothesis1 = item['choice_id: 0']
    hypothesis2 = item['choice_id: 1']
    hypothesis3 = item['choice_id: 2']
    ask_for = item['ask-for']
    task = "cause" if ask_for == "cause" else "effect"
#     return f"premise: {premise} hypothesis 1: {hypothesis1} hypothesis 2: {hypothesis2} task: {task}"
    return f"Given the premise: {premise}; what is the {task}? Is it hypothesis 1: {hypothesis1}; OR hypothesis 2: {hypothesis2}; OR hypothesis 3: {hypothesis3}? Pick one and do not explain."

# Function to query the Gemini model
def query_gemini(query, model):
    chat = model.start_chat(history=[])
    response = chat.send_message(query)
    return response.text

# Load the COPA data
copa_data = load_copa_data('/content/drive/MyDrive/Datasets/causalnetcd.json')

# %%
import random
import time
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


def compute_metrics(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average='weighted')
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    return [accuracy, f1, precision, recall]


responses_file = '/content/drive/MyDrive/Datasets/causalnetcd_responses_' + str(run) + '.jsonl'
# Function to evaluate accuracy with Gemini
def evaluate_accuracy_with_gemini(data, model):
    correct_count = 0
    total_items = len(data)
    skipped_items = 0

    try:
        with open(responses_file, 'r', encoding='utf-8') as file:
            saved_responses = [json.loads(line) for line in file]
        print("Loaded saved responses.")
        return saved_responses
    except FileNotFoundError:
        for index, item in enumerate(data):
            try:
                query = format_copa_query_for_gemini(item)
                print(f"\nProcessing item {index + 1}/{total_items}...")

                response = query_gemini(query, model)
                print(f"Generated Response: {response}")

                correct_hypothesis = item['choice_id: ' + str(item['label'])]
                print(f"Correct Hypothesis: Hypothesis: {item['label'] + 1}, {correct_hypothesis}")
                acts.append(item['label'])

                is_correct = is_response_correct(response, item)

                if is_correct:
                    print(f"Item {index + 1}: Correct")
                    correct_count += 1
                    preds.append(item['label'])
                else:
                    print(f"Item {index + 1}: Incorrect")
                    preds.append(0 if item['label'] else 1)


            except Exception as e:
                print(f"Item {index + 1} skipped due to internal server error: {e}")
                skipped_items += 1
                time.sleep(5)

    # Adjust total_items to exclude skipped items for accuracy calculation
    total_items -= skipped_items
    accuracy = correct_count / total_items if total_items > 0 else 0
    print(f"\nProcessed Items: {total_items}, Skipped Items: {skipped_items}")
    print(f"Accuracy: {accuracy * 100:.2f}%")
    return accuracy


# Evaluate accuracy with Gemini
acts, preds = [], []  # acts: ground truth
accuracy = evaluate_accuracy_with_gemini(copa_data, gemini_model)
print(accuracy)
print(f"Accuracy with Gemini: {accuracy * 100:.3f}%")

with open(responses_file, 'w', encoding='utf-8') as file:
        for response in saved_responses:
            file.write(json.dumps(response) + '\n')
        print("Responses saved.")

sklearn_accuracy, f1val, precisionval, recallval = compute_metrics(acts, preds)
print(f"Accuracy: {accuracy * 100:.3f}%")
print(f"sklearn Accuracy: {sklearn_accuracy * 100:.3f}%")
print(f"F1: {f1val * 100:.3f}%")
print(f"Precision: {precisionval * 100:.3f}%")
print(f"Recall: {recallval * 100:.3f}%")
# Out:
# Streaming output truncated to the last 5000 lines.
# Correct Hypothesis: Hypothesis: 1, The recycling program might have inadvertently encouraged more consumption, leading to more waste.
# Item 6: Correct
#
# Processing item 7/1000...
# Generated Response: Hypothesis 3: The financial security provided by UBI encouraged entrepreneurial ventures.
# Correct Hypothesis: Hypothesis: 3, The financial security provided by UBI encouraged entrepreneurial ventures.
# Item 7: Correct
#
# Processing item 8/1000...
# Generated Response: Hypothesis 3: The increase in green spaces indirectly reduced pollution by promoting a cleaner urban environment.
# Correct Hypothesis: Hypothesis: 3, The increase in green spaces indirectly reduced pollution by promoting a cleaner urban environment.
# Item 8: Correct
#
# Processing item 9/1000...
# Generated Response: Hypothesis 3: Renewable energy projects created new job opportunities, contributing to lower unemployment.
# Correct Hypothesis: Hypothesis: 3, Renewable energy projects created new job opportunities, contributing to lower unemployment.
# Item 9: Correct
#
# Processing item 10/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 2, The increase in tourism led to greater awareness and compliance with fishing regulations.
# Item 10: Incorrect
#
# Processing item 11/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, The reduction in plastic waste improved natural habitats, indirectly benefiting wildlife.
# Item 11: Correct
#
# Processing item 12/1000...
# Generated Response: Hypothesis 3: The availability of online learning platforms provided alternative education pathways.
# Correct Hypothesis: Hypothesis: 3, The availability of online learning platforms provided alternative education pathways.
# Item 12: Correct
#
# Processing item 13/1000...
# Generated Response: Hypothesis 3: The ban on diesel vehicles directly contributed to cleaner air, while the other factors played a supportive role.
# Correct Hypothesis: Hypothesis: 3, The ban on diesel vehicles directly contributed to cleaner air, while the other factors played a supportive role.
# Item 13: Correct
#
# Processing item 14/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, The new tax law created a more favorable environment for small businesses, encouraging entrepreneurship.
# Item 14: Correct
#
# Processing item 15/1000...
# Generated Response: Hypothesis 1: The nation's investment in space research directly inspired students to pursue STEM.
# Correct Hypothesis: Hypothesis: 2, Popular science fiction movies and virtual reality technology made STEM subjects more appealing to young minds.
# Item 15: Incorrect
#
# Processing item 16/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, The 'green roof' policy created more natural cooling areas, contributing to the reduction of heat islands.
# Item 16: Correct
#
# Processing item 17/1000...
# Generated Response: Hypothesis 1: Organic farming practices led to healthier diets, contributing to longer life expectancy.
# Correct Hypothesis: Hypothesis: 1, Organic farming practices led to healthier diets, contributing to longer life expectancy.
# Item 17: Correct
#
# Processing item 18/1000...
# Generated Response: Hypothesis 2: The enhancement of public libraries created spaces that fostered community interaction and learning.
# Correct Hypothesis: Hypothesis: 2, The enhancement of public libraries created spaces that fostered community interaction and learning.
# Item 18: Correct
#
# Processing item 19/1000...
# Generated Response: Hypothesis 1: The increase in bicycle usage reduced reliance on motor vehicles, contributing to lower pollution levels.
# Correct Hypothesis: Hypothesis: 1, The increase in bicycle usage reduced reliance on motor vehicles, contributing to lower pollution levels.
# Item 19: Correct
#
# Processing item 20/1000...
# Generated Response: Hypothesis 3: The digital literacy program empowered more citizens to engage in tech entrepreneurship.
# Correct Hypothesis: Hypothesis: 3, The digital literacy program empowered more citizens to engage in tech entrepreneurship.
# Item 20: Correct
#
# Processing item 21/1000...
# Generated Response: Hypothesis 2: Public art projects provided a constructive outlet for youth, contributing to lower crime rates.
# Correct Hypothesis: Hypothesis: 2, Public art projects provided a constructive outlet for youth, contributing to lower crime rates.
# Item 21: Correct
#
# Processing item 22/1000...
# Generated Response: Hypothesis 3: Advancements in battery technology made renewable energy sources more viable, reducing reliance on fossil fuels.
# Correct Hypothesis: Hypothesis: 3, Advancements in battery technology made renewable energy sources more viable, reducing reliance on fossil fuels.
# Item 22: Correct
#
# Processing item 23/1000...
# Generated Response: Hypothesis 3: Free Wi-Fi in public areas attracted more entrepreneurs and tourists, boosting local business growth.
# Correct Hypothesis: Hypothesis: 3, Free Wi-Fi in public areas attracted more entrepreneurs and tourists, boosting local business growth.
# Item 23: Correct
#
# Processing item 24/1000...
# Generated Response: Hypothesis 2: Investment in nuclear energy led to reduced reliance on coal, thereby improving air quality.
# Correct Hypothesis: Hypothesis: 2, Investment in nuclear energy led to reduced reliance on coal, thereby improving air quality.
# Item 24: Correct
#
# Processing item 25/1000...
# Generated Response: Hypothesis 2: Mandatory coding classes equipped youth with the skills to participate in the burgeoning global tech industry.
# Correct Hypothesis: Hypothesis: 2, Mandatory coding classes equipped youth with the skills to participate in the burgeoning global tech industry.
# Item 25: Correct
#
# Processing item 26/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, The increase in urban green spaces provided residents with a natural, calming environment, contributing to stress reduction.
# Item 26: Correct
#
# Processing item 27/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, The ban on plastic bags significantly reduced marine pollution, indirectly benefiting marine biodiversity.
# Item 27: Correct
#
# Processing item 28/1000...
# Generated Response: Hypothesis 2: The public health campaign effectively raised awareness about the dangers of smoking, leading to a decline in smoking rates.
# Correct Hypothesis: Hypothesis: 2, The public health campaign effectively raised awareness about the dangers of smoking, leading to a decline in smoking rates.
# Item 28: Correct
#
# Processing item 29/1000...
# Generated Response: Hypothesis 3: High-speed internet access enabled residents to participate more actively in the global e-commerce trend.
# Correct Hypothesis: Hypothesis: 3, High-speed internet access enabled residents to participate more actively in the global e-commerce trend.
# Item 29: Correct
#
# Processing item 30/1000...
# Generated Response: Hypothesis 3: The new public transport system provided an effective alternative to car use, easing traffic congestion.
# Correct Hypothesis: Hypothesis: 3, The new public transport system provided an effective alternative to car use, easing traffic congestion.
# Item 30: Correct
#
# Processing item 31/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, The increase in minimum wage provided employees with more financial security, leading to lower turnover.
# Item 31: Correct
#
# Processing item 32/1000...
# Generated Response: Hypothesis 2: Advancements in solar panel technology made renewable energy more cost-effective.
# Correct Hypothesis: Hypothesis: 2, Advancements in solar panel technology made renewable energy more cost-effective.
# Item 32: Correct
#
# Processing item 33/1000...
# Generated Response: Hypothesis 1: Advancements in mobile technology made telemedicine more accessible in rural areas.
# Correct Hypothesis: Hypothesis: 1, Advancements in mobile technology made telemedicine more accessible in rural areas.
# Item 33: Correct
#
# Processing item 34/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 2, The rise in e-cigarette popularity offered an alternative to traditional smoking, contributing to the decrease.
# Item 34: Incorrect
#
# Processing item 35/1000...
# Generated Response: Hypothesis 2: Advancements in energy-saving technologies complemented the green building standards, enhancing overall energy efficiency.
# Correct Hypothesis: Hypothesis: 2, Advancements in energy-saving technologies complemented the green building standards, enhancing overall energy efficiency.
# Item 35: Correct
#
# Processing item 36/1000...
# Generated Response: Hypothesis 1: The decrease in urban pollution contributed to a healthier environment, indirectly affecting community wellbeing.
# Correct Hypothesis: Hypothesis: 1, The decrease in urban pollution contributed to a healthier environment, indirectly affecting community wellbeing.
# Item 36: Correct
#
# Processing item 37/1000...
# Generated Response: Hypothesis 2: The global trend towards digitalization created a conducive environment for innovation, complementing the focus on STEM education.
# Correct Hypothesis: Hypothesis: 2, The global trend towards digitalization created a conducive environment for innovation, complementing the focus on STEM education.
# Item 37: Correct
#
# Processing item 38/1000...
# Generated Response: Hypothesis 3: The growth of urban green spaces provided a more peaceful and healthy living environment, contributing to quality of life.
# Correct Hypothesis: Hypothesis: 3, The growth of urban green spaces provided a more peaceful and healthy living environment, contributing to quality of life.
# Item 38: Correct
#
# Processing item 39/1000...
# Generated Response: Hypothesis 2: Improvements in electric vehicle technology made them more accessible, contributing to reduced pollution.
# Correct Hypothesis: Hypothesis: 2, Improvements in electric vehicle technology made them more accessible, contributing to reduced pollution.
# Item 39: Correct
#
# Processing item 40/1000...
# Generated Response: Hypothesis 3: Advancements in internet technology made online learning more accessible and appealing.
# Correct Hypothesis: Hypothesis: 3, Advancements in internet technology made online learning more accessible and appealing.
# Item 40: Correct
#
# Processing item 41/1000...
# Generated Response: Hypothesis 3: Stricter traffic laws led to more cautious driving behaviors, contributing to fewer accidents.
# Correct Hypothesis: Hypothesis: 3, Stricter traffic laws led to more cautious driving behaviors, contributing to fewer accidents.
# Item 41: Correct
#
# Processing item 42/1000...
# Generated Response: Hypothesis 1: Advancements in wind and solar technology made renewable energy more feasible and efficient.
# Correct Hypothesis: Hypothesis: 1, Advancements in wind and solar technology made renewable energy more feasible and efficient.
# Item 42: Correct
#
# Processing item 43/1000...
# Generated Response: Hypothesis 1: Community literacy programs were the primary factor in improving literacy rates.
# Correct Hypothesis: Hypothesis: 3, New educational technologies made learning more accessible and engaging, contributing to higher literacy rates.
# Item 43: Incorrect
#
# Processing item 44/1000...
# Generated Response: Hypothesis 3: The trend of drier weather patterns was the primary reason for reduced flood damage.
# Correct Hypothesis: Hypothesis: 2, Advancements in weather forecasting technology allowed for better preparation and response to potential flooding.
# Item 44: Incorrect
#
# Processing item 45/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, Improvements in public transportation offered a cleaner alternative to private car use, aiding in emission reduction.
# Item 45: Correct
#
# Processing item 46/1000...
# Generated Response: Hypothesis 1: Advancements in energy storage technologies made renewable energy sources like solar more reliable, contributing to increased production.
# Correct Hypothesis: Hypothesis: 1, Advancements in energy storage technologies made renewable energy sources like solar more reliable, contributing to increased production.
# Item 46: Correct
#
# Processing item 47/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, Sustainable farming practices increased the efficiency and sustainability of food production, contributing to food security.
# Item 47: Correct
#
# Processing item 48/1000...
# Generated Response: Hypothesis 3: The anti-littering campaign was the primary factor for the reduction in urban pollution.
# Correct Hypothesis: Hypothesis: 2, Stricter waste management regulations effectively reduced the amount of litter and pollution in the city.
# Item 48: Incorrect
#
# Processing item 49/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, The rise in internet connectivity made e-commerce more accessible to rural populations, contributing to its growth.
# Item 49: Correct
#
# Processing item 50/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 2, New policy promoting neighborhood initiatives encouraged residents to participate more in local activities, including urban gardening.
# Item 50: Incorrect
#
# Processing item 51/1000...
# Generated Response: Hypothesis 1: Increased public awareness about water conservation led to more mindful usage, augmenting the effect of the water-saving devices.
# Correct Hypothesis: Hypothesis: 1, Increased public awareness about water conservation led to more mindful usage, augmenting the effect of the water-saving devices.
# Item 51: Correct
#
# Processing item 52/1000...
# Generated Response: Hypothesis 1: The investment in renewable energy research alone triggered the increase in green technology patents.
# Correct Hypothesis: Hypothesis: 2, Global environmental agreements raised awareness and created a conducive environment for green technology innovation.
# Item 52: Incorrect
#
# Processing item 53/1000...
# Generated Response: Hypothesis 3: Technological advancements in solar panels made them more efficient and cost-effective, contributing to lower energy costs.
# Correct Hypothesis: Hypothesis: 3, Technological advancements in solar panels made them more efficient and cost-effective, contributing to lower energy costs.
# Item 53: Correct
#
# Processing item 54/1000...
# Generated Response: Hypothesis 1: Smart traffic management systems were the primary factor in improving traffic flow.
# Correct Hypothesis: Hypothesis: 2, The increase in electric vehicle usage led to changes in driving patterns, complementing the smart traffic management systems.
# Item 54: Incorrect
#
# Processing item 55/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, Advancements in medical technology provided more effective treatment options, contributing to better health outcomes.
# Item 55: Correct
#
# Processing item 56/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, The growth in urban tree planting provided natural cooling, which along with green roofing, helped reduce heat islands.
# Item 56: Correct
#
# Processing item 57/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, Improvements in internet infrastructure made online filing more accessible, contributing to its efficiency.
# Item 57: Correct
#
# Processing item 58/1000...
# Generated Response: Hypothesis 2: The trend towards healthier eating habits contributed to improved overall public health.
# Correct Hypothesis: Hypothesis: 2, The trend towards healthier eating habits contributed to improved overall public health.
# Item 58: Correct
#
# Processing item 59/1000...
# Generated Response: Hypothesis 3: The rise in entrepreneurship education provided the necessary skills and knowledge, fueling small business growth.
# Correct Hypothesis: Hypothesis: 3, The rise in entrepreneurship education provided the necessary skills and knowledge, fueling small business growth.
# Item 59: Correct
#
# Processing item 60/1000...
# Generated Response: Hypothesis 2: The recycling program was the primary reason for the decrease in landfill waste.
# Correct Hypothesis: Hypothesis: 3, The increase in community environmental awareness led to more responsible waste management practices, reducing landfill waste.
# Item 60: Incorrect
#
# Processing item 61/1000...
# Generated Response: Hypothesis 2: The reduction in the use of private vehicles led to lower emissions, complementing the effect of electric buses.
# Correct Hypothesis: Hypothesis: 2, The reduction in the use of private vehicles led to lower emissions, complementing the effect of electric buses.
# Item 61: Correct
#
# Processing item 62/1000...
# Generated Response: Hypothesis 1: The national fitness campaign was the primary factor in reducing obesity rates.
# Correct Hypothesis: Hypothesis: 3, Healthy eating programs provided better nutritional education, contributing to lower obesity rates.
# Item 62: Incorrect
#
# Processing item 63/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, The city-wide campaign effectively promoted local tourism, attracting more visitors.
# Item 63: Correct
#
# Processing item 64/1000...
# Generated Response: Hypothesis 3: Government investment in rural healthcare facilities was the primary reason for improved access.
# Correct Hypothesis: Hypothesis: 2, The increase in telemedicine services provided remote access to healthcare, complementing the physical healthcare facilities.
# Item 64: Incorrect
#
# Processing item 65/1000...
# Generated Response: Hypothesis 1: The rise in neighborhood associations fostered a stronger sense of community, encouraging more engagement.
# Correct Hypothesis: Hypothesis: 1, The rise in neighborhood associations fostered a stronger sense of community, encouraging more engagement.
# Item 65: Correct
#
# Processing item 66/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, The rise in energy conservation awareness led to more mindful energy usage by residents, complementing the impact of energy-efficient appliances.
# Item 66: Correct
#
# Processing item 67/1000...
# Generated Response: Hypothesis 3: Advancements in renewable energy technology made it more efficient and cost-effective, encouraging the shift from fossil fuels.
# Correct Hypothesis: Hypothesis: 3, Advancements in renewable energy technology made it more efficient and cost-effective, encouraging the shift from fossil fuels.
# Item 67: Correct
#
# Processing item 68/1000...
# Generated Response: Hypothesis 2: The city-wide clean air campaign was the primary reason for the improvement in air quality.
# Correct Hypothesis: Hypothesis: 3, The increase in electric vehicle usage contributed to lower emissions, aiding in the reduction of air pollution.
# Item 68: Incorrect
#
# Processing item 69/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, Improvements in dietary habits contributed to better overall health, complementing the availability of sports facilities.
# Item 69: Correct
#
# Processing item 70/1000...
# Generated Response: Hypothesis 2: The decrease in vehicle emissions played a significant role in reducing air pollutants, aiding the impact of the tree planting initiative.
# Correct Hypothesis: Hypothesis: 2, The decrease in vehicle emissions played a significant role in reducing air pollutants, aiding the impact of the tree planting initiative.
# Item 70: Correct
#
# Processing item 71/1000...
# Generated Response: Hypothesis 1: The enhanced cycling infrastructure was the sole factor in increasing the number of cycling commuters.
# Correct Hypothesis: Hypothesis: 3, Improvements in bike technology made cycling more appealing and accessible, contributing to its popularity.
# Item 71: Incorrect
#
# Processing item 72/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, The global trend in digital transformation created a conducive environment for online business growth.
# Item 72: Correct
#
# Processing item 73/1000...
# Generated Response: The strict water conservation measures were the sole factor in the reduction in water issues.
# Correct Hypothesis: Hypothesis: 2, Advancements in water recycling technology increased the efficiency of water use, contributing to the reduction in scarcity.
# Item 73: Incorrect
#
# Processing item 74/1000...
# Generated Response: Hypothesis 3: Enhancements to cultural attractions drew more visitors, complementing the impact of the public art initiative.
# Correct Hypothesis: Hypothesis: 3, Enhancements to cultural attractions drew more visitors, complementing the impact of the public art initiative.
# Item 74: Correct
#
# Processing item 75/1000...
# Generated Response: Hypothesis 3: The park beautification projects made the parks more attractive, encouraging more visitors.
# Correct Hypothesis: Hypothesis: 3, The park beautification projects made the parks more attractive, encouraging more visitors.
# Item 75: Correct
#
# Processing item 76/1000...
# Generated Response: Hypothesis 1: The country's investment in science education was the primary driver of the surge in research and innovation.
# Correct Hypothesis: Hypothesis: 2, Private sector funding provided additional resources, boosting research and innovation.
# Item 76: Incorrect
#
# Processing item 77/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, Improvements in waste management systems effectively reduced the amount of waste reaching marine environments.
# Item 77: Correct
#
# Processing item 78/1000...
# Generated Response: Hypothesis 2: Smart street lighting was the primary reason for both the reduction in energy consumption and improved public safety.
# Correct Hypothesis: Hypothesis: 3, Community safety initiatives fostered a safer environment, complementing the impact of smart street lighting.
# Item 78: Incorrect
#
# Processing item 79/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, Community-led health initiatives encouraged more communal activities and interactions, fostering cohesion.
# Item 79: Correct
#
# Processing item 80/1000...
# Generated Response: Hypothesis 1: Public health research investment was the primary driver for the advancement in healthcare quality.
# Correct Hypothesis: Hypothesis: 2, International collaboration in health science led to the sharing of knowledge and best practices, enhancing healthcare quality.
# Item 80: Incorrect
#
# Processing item 81/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, Noise reduction policies created a more serene urban environment, contributing to lower stress levels.
# Item 81: Correct
#
# Processing item 82/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 2, Advancements in energy storage technologies increased the efficiency and reduced the cost of renewable energy.
# Item 82: Incorrect
#
# Processing item 83/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, The marketing campaign effectively attracted tourists by highlighting the town's unique cultural attractions.
# Item 83: Correct
#
# Processing item 84/1000...
# Generated Response: Hypothesis 3: The growth in online educational resources provided accessible learning opportunities, enhancing digital literacy.
# Correct Hypothesis: Hypothesis: 3, The growth in online educational resources provided accessible learning opportunities, enhancing digital literacy.
# Item 84: Correct
#
# Processing item 85/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, Sustainable farming practices increased the availability of local, healthy food options, enhancing food security.
# Item 85: Correct
#
# Processing item 86/1000...
# Generated Response: hypothesis 3
# Correct Hypothesis: Hypothesis: 2, Advancements in weather forecasting technology allowed for better preparation and response to potential flooding, reducing damages.
# Item 86: Incorrect
#
# Processing item 87/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 1, Advancements in renewable energy technology made green energy projects more viable and efficient.
# Item 87: Incorrect
#
# Processing item 88/1000...
# Generated Response: Hypothesis 3: The trend towards remote working reduced the number of vehicles on the road, aiding in easing traffic conditions.
# Correct Hypothesis: Hypothesis: 3, The trend towards remote working reduced the number of vehicles on the road, aiding in easing traffic conditions.
# Item 88: Correct
#
# Processing item 89/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, The rise in digital literacy enabled citizens to better engage with digital services, improving overall efficiency.
# Item 89: Correct
#
# Processing item 90/1000...
# Generated Response: Community environmental education programs alone significantly reduced and waste in public areas
# Correct Hypothesis: Hypothesis: 3, The increase in recycling facilities provided more options for waste disposal, contributing to less littering.
# Item 90: Incorrect
#
# Processing item 91/1000...
# Generated Response: Hypothesis 3: The energy conservation campaign was the primary reason for reduced energy consumption and improved visibility.
# Correct Hypothesis: Hypothesis: 2, The introduction of solar-powered public lighting provided an additional sustainable energy source, enhancing the town's lighting efficiency.
# Item 91: Incorrect
#
# Processing item 92/1000...
# Generated Response: Hypothesis 1: Advancements in water-saving technologies enhanced the efficiency of water use, complementing the impact of the conservation laws.
# Correct Hypothesis: Hypothesis: 1, Advancements in water-saving technologies enhanced the efficiency of water use, complementing the impact of the conservation laws.
# Item 92: Correct
#
# Processing item 93/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, Advancements in eco-friendly building materials made sustainable construction more feasible and attractive.
# Item 93: Correct
#
# Processing item 94/1000...
# Generated Response: Hypothesis 3: The investment in high-speed internet infrastructure was the primary reason for the boost in e-commerce and remote working.
# Correct Hypothesis: Hypothesis: 1, The trend towards digital transformation enabled more businesses to adapt to e-commerce and remote working models.
# Item 94: Incorrect
#
# Processing item 95/1000...
# Generated Response: Hypothesis 3: The national health and fitness program was the sole factor in reducing public health issues.
# Correct Hypothesis: Hypothesis: 2, The trend towards healthier eating habits contributed to better overall health, reducing health issues.
# Item 95: Incorrect
#
# Processing item 96/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 3, The growth in local artisan businesses showcased the city's unique culture, attracting tourists and boosting local pride.
# Item 96: Incorrect
#
# Processing item 97/1000...
# Generated Response: Hypothesis 3: The global push for renewable energy was the primary driver for the increase in green energy installations.
# Correct Hypothesis: Hypothesis: 2, Advancements in green technology made solar panels and wind turbines more efficient and cost-effective.
# Item 97: Incorrect
#
# Processing item 98/1000...
# Generated Response: Hypothesis 1: Pedestrian-friendly zones were the primary reason for the improvement in urban livability.
# Correct Hypothesis: Hypothesis: 2, The trend towards sustainable urban planning led to more green spaces and less congestion, enhancing livability.
# Item 98: Incorrect
#
# Processing item 99/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, The increase in fitness facilities provided more opportunities for regular exercise, contributing to better public health.
# Item 99: Correct
#
# Processing item 100/1000...
# Generated Response: Hypothesis 3: The country's investment in arts and culture was the primary driver for the increase in tourism and cultural engagement.
# Correct Hypothesis: Hypothesis: 2, Global cultural exchange programs expanded people's interest in diverse cultures, boosting tourism and engagement.
# Item 100: Incorrect
#
# Processing item 101/1000...
# Item 101 skipped due to internal server error: finish_reason: SAFETY
# index: 0
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: MEDIUM
# }
# safety_ratings {
#   category: HARM_CATEGORY_DANGEROUS_CONTENT
#   probability: NEGLIGIBLE
# }
#
#
# Processing item 102/1000...
# Generated Response: Hypothesis 1: Advancements in renewable energy technology made green energy projects more viable and efficient.
# Correct Hypothesis: Hypothesis: 1, Advancements in renewable energy technology made green energy projects more viable and efficient.
# Item 102: Correct
#
# Processing item 103/1000...
# Generated Response: Hypothesis 1: The growth in online educational resources provided accessible learning opportunities, enhancing digital literacy.
# Correct Hypothesis: Hypothesis: 1, The growth in online educational resources provided accessible learning opportunities, enhancing digital literacy.
# Item 103: Correct
#
# Processing item 104/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, The jellyfish blooms could have deterred tourists despite the beach's accolades.
# Item 104: Correct
#
# Processing item 105/1000...
# Generated Response: Hypothesis 3: The local food market was the sole factor in enhancing community cohesion.
# Correct Hypothesis: Hypothesis: 2, Community-led health initiatives encouraged more communal activities and interactions, fostering cohesion.
# Item 105: Incorrect
#
# Processing item 106/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, Advancements in mobile technology made telemedicine more accessible in rural areas.
# Item 106: Correct
#
# Processing item 107/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, The rise in neighborhood associations fostered a stronger sense of community, encouraging more engagement.
# Item 107: Correct
#
# Processing item 108/1000...
# Generated Response: Hypothesis 3: Sustainable farming practices increased the efficiency and sustainability of food production, contributing to food security.
# Correct Hypothesis: Hypothesis: 3, Sustainable farming practices increased the efficiency and sustainability of food production, contributing to food security.
# Item 108: Correct
#
# Processing item 109/1000...
# Generated Response: Hypothesis 2: The new public transport system provided an effective alternative to car use, easing traffic congestion.
# Correct Hypothesis: Hypothesis: 2, The new public transport system provided an effective alternative to car use, easing traffic congestion.
# Item 109: Correct
#
# Processing item 110/1000...
# Generated Response: Hypothesis 3: The new tax law created a more favorable environment for small businesses, encouraging entrepreneurship.
# Correct Hypothesis: Hypothesis: 3, The new tax law created a more favorable environment for small businesses, encouraging entrepreneurship.
# Item 110: Correct
#
# Processing item 111/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, The growth of urban green spaces provided a more peaceful and healthy living environment, contributing to quality of life.
# Item 111: Correct
#
# Processing item 112/1000...
# Generated Response: Hypothesis 1: The digital literacy program empowered more citizens to engage in tech entrepreneurship.
# Correct Hypothesis: Hypothesis: 1, The digital literacy program empowered more citizens to engage in tech entrepreneurship.
# Item 112: Correct
#
# Processing item 113/1000...
# Generated Response: Hypothesis 1: The park beautification projects made the parks more attractive, encouraging more visitors.
# Correct Hypothesis: Hypothesis: 1, The park beautification projects made the parks more attractive, encouraging more visitors.
# Item 113: Correct
#
# Processing item 114/1000...
# Generated Response: Hypothesis 1: Community wellness programs were the primary reason for the reduction in stress levels.
# Correct Hypothesis: Hypothesis: 3, Noise reduction policies created a more serene urban environment, contributing to lower stress levels.
# Item 114: Incorrect
#
# Processing item 115/1000...
# Generated Response: Hypothesis 1: Improvements in public transportation offered a cleaner alternative to private car use, aiding in emission reduction.
# Correct Hypothesis: Hypothesis: 1, Improvements in public transportation offered a cleaner alternative to private car use, aiding in emission reduction.
# Item 115: Correct
#
# Processing item 116/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, The growth in online educational resources provided accessible learning opportunities, enhancing digital literacy.
# Item 116: Correct
#
# Processing item 117/1000...
# Generated Response: Hypothesis 2: The rise in entrepreneurship education provided the necessary skills and knowledge, fueling small business growth.
# Correct Hypothesis: Hypothesis: 2, The rise in entrepreneurship education provided the necessary skills and knowledge, fueling small business growth.
# Item 117: Correct
#
# Processing item 118/1000...
# Generated Response: Hypothesis 3: The rise in entrepreneurship education provided the necessary skills and knowledge, fueling small business growth.
# Correct Hypothesis: Hypothesis: 3, The rise in entrepreneurship education provided the necessary skills and knowledge, fueling small business growth.
# Item 118: Correct
#
# Processing item 119/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, Advancements in energy-saving technologies complemented the green building standards, enhancing overall energy efficiency.
# Item 119: Correct
#
# Processing item 120/1000...
# Generated Response: Hypothesis 3: Urban gardening projects were the primary reason for enhanced community engagement.
# Correct Hypothesis: Hypothesis: 2, New policy promoting neighborhood initiatives encouraged residents to participate more in local activities, including urban gardening.
# Item 120: Incorrect
#
# Processing item 121/1000...
# Generated Response: Hypothesis 1: Private sector funding provided additional resources, boosting research and innovation.
# Correct Hypothesis: Hypothesis: 1, Private sector funding provided additional resources, boosting research and innovation.
# Item 121: Correct
#
# Processing item 122/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 2, Improvements in public transportation offered a cleaner alternative to private car use, aiding in emission reduction.
# Item 122: Incorrect
#
# Processing item 123/1000...
# Generated Response: Hypothesis 2: Advancements in internet technology made online learning more accessible and appealing.
# Correct Hypothesis: Hypothesis: 2, Advancements in internet technology made online learning more accessible and appealing.
# Item 123: Correct
#
# Processing item 124/1000...
# Generated Response: Hypothesis 3: High-speed internet access enabled residents to participate more actively in the global e-commerce trend.
# Correct Hypothesis: Hypothesis: 3, High-speed internet access enabled residents to participate more actively in the global e-commerce trend.
# Item 124: Correct
#
# Processing item 125/1000...
# Generated Response: Hypothesis 3: The expansion of green spaces was the sole factor in decreasing urban stress levels.
# Correct Hypothesis: Hypothesis: 1, Noise reduction policies created a more serene urban environment, contributing to lower stress levels.
# Item 125: Incorrect
#
# Processing item 126/1000...
# Generated Response:  Hypothesis 2: The increase in bicycle usage reduced reliance on motor vehicles, contributing to lower pollution levels.
# Correct Hypothesis: Hypothesis: 2, The increase in bicycle usage reduced reliance on motor vehicles, contributing to lower pollution levels.
# Item 126: Correct
#
# Processing item 127/1000...
# Generated Response: Hypothesis 1: Sustainable farming practices increased the efficiency and sustainability of food production, contributing to food security.
# Correct Hypothesis: Hypothesis: 1, Sustainable farming practices increased the efficiency and sustainability of food production, contributing to food security.
# Item 127: Correct
#
# Processing item 128/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, The trend towards healthier eating habits contributed to improved overall public health.
# Item 128: Correct
#
# Processing item 129/1000...
# Generated Response: Hypothesis 2: The jellyfish blooms could have deterred tourists despite the beach's accolades.
# Correct Hypothesis: Hypothesis: 2, The jellyfish blooms could have deterred tourists despite the beach's accolades.
# Item 129: Correct
#
# Processing item 130/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 3, The increase in electric vehicle usage contributed to lower emissions, aiding in the reduction of air pollution.
# Item 130: Incorrect
#
# Processing item 131/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, The trend towards healthier eating habits contributed to better overall health, reducing health issues.
# Item 131: Correct
#
# Processing item 132/1000...
# Generated Response: Hypothesis 1: New policy promoting neighborhood initiatives encouraged residents to participate more in local activities, including urban gardening.
# Correct Hypothesis: Hypothesis: 1, New policy promoting neighborhood initiatives encouraged residents to participate more in local activities, including urban gardening.
# Item 132: Correct
#
# Processing item 133/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, Renewable energy projects created new job opportunities, contributing to lower unemployment.
# Item 133: Correct
#
# Processing item 134/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, The global trend towards digitalization created a conducive environment for innovation, complementing the focus on STEM education.
# Item 134: Correct
#
# Processing item 135/1000...
# Generated Response: Hypothesis 1: The jellyfish blooms could have deterred tourists despite the beach's accolades.
# Correct Hypothesis: Hypothesis: 1, The jellyfish blooms could have deterred tourists despite the beach's accolades.
# Item 135: Correct
#
# Processing item 136/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, The increase in bicycle usage reduced reliance on motor vehicles, contributing to lower pollution levels.
# Item 136: Correct
#
# Processing item 137/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, The ban on diesel vehicles directly contributed to cleaner air, while the other factors played a supportive role.
# Item 137: Correct
#
# Processing item 138/1000...
# Generated Response: Hypothesis 3: Advancements in energy storage technologies increased the efficiency and reduced the cost of renewable energy.
# Correct Hypothesis: Hypothesis: 3, Advancements in energy storage technologies increased the efficiency and reduced the cost of renewable energy.
# Item 138: Correct
#
# Processing item 139/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, The park beautification projects made the parks more attractive, encouraging more visitors.
# Item 139: Correct
#
# Processing item 140/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 2, The trend towards healthier eating habits contributed to improved overall public health.
# Item 140: Incorrect
#
# Processing item 141/1000...
# Generated Response: Hypothesis 3: Investment in nuclear energy led to reduced reliance on coal, thereby improving air quality.
# Correct Hypothesis: Hypothesis: 3, Investment in nuclear energy led to reduced reliance on coal, thereby improving air quality.
# Item 141: Correct
#
# Processing item 142/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, The trend towards healthier eating habits contributed to better overall health, reducing health issues.
# Item 142: Correct
#
# Processing item 143/1000...
# Generated Response: Hypothesis 1: The celebrity's influence changed teenagers' perceptions more significantly than expected.
# Correct Hypothesis: Hypothesis: 1, The celebrity's influence changed teenagers' perceptions more significantly than expected.
# Item 143: Correct
#
# Processing item 144/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 1, The trend towards digital transformation enabled more businesses to adapt to e-commerce and remote working models.
# Item 144: Incorrect
#
# Processing item 145/1000...
# Generated Response: Health education programs were the primary reason for the improvement in public health
# Correct Hypothesis: Hypothesis: 1, Advancements in medical technology provided more effective treatment options, contributing to better health outcomes.
# Item 145: Incorrect
#
# Processing item 146/1000...
# Generated Response: Hypothesis 1: The 'green roof' policy created more natural cooling areas, contributing to the reduction of heat islands.
# Correct Hypothesis: Hypothesis: 1, The 'green roof' policy created more natural cooling areas, contributing to the reduction of heat islands.
# Item 146: Correct
#
# Processing item 147/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, Public art projects provided a constructive outlet for youth, contributing to lower crime rates.
# Item 147: Correct
#
# Processing item 148/1000...
# Generated Response: hypothesis 1
# Correct Hypothesis: Hypothesis: 1, The increase in minimum wage provided employees with more financial security, leading to lower turnover.
# Item 148: Correct
#
# Processing item 149/1000...
# Generated Response: Hypothesis 2: Public health research investment was the primary driver for the advancement in healthcare quality.
# Correct Hypothesis: Hypothesis: 3, International collaboration in health science led to the sharing of knowledge and best practices, enhancing healthcare quality.
# Item 149: Incorrect
#
# Processing item 150/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, Advancements in water-saving technologies enhanced the efficiency of water use, complementing the impact of the conservation laws.
# Item 150: Correct
#
# Processing item 151/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, Advancements in medical technology provided more effective treatment options, contributing to better health outcomes.
# Item 151: Correct
#
# Processing item 152/1000...
# Generated Response: The cause of the secondary secondary effects on: the scientific research and the sector funding couldn't explain the increase in research must coming from other reasons that the explanation doesn't explain so the other 2 options are not real. Therefore, option 1 and 2 are not good options for your secondary reasons on research. Therefore, option 3 is the best choice for your circumstances and the secondary effects of your decision on the Research and Development
# Correct Hypothesis: Hypothesis: 2, Private sector funding provided additional resources, boosting research and innovation.
# Item 152: Incorrect
#
# Processing item 153/1000...
# Generated Response: Hypothesis 2: The jellyfish blooms could have deterred tourists despite the beach's accolades.
# Correct Hypothesis: Hypothesis: 2, The jellyfish blooms could have deterred tourists despite the beach's accolades.
# Item 153: Correct
#
# Processing item 154/1000...
# Generated Response: Hypothesis 3: The increase in green spaces indirectly reduced pollution by promoting a cleaner urban environment.
# Correct Hypothesis: Hypothesis: 3, The increase in green spaces indirectly reduced pollution by promoting a cleaner urban environment.
# Item 154: Correct
#
# Processing item 155/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, The public health campaign effectively raised awareness about the dangers of smoking, leading to a decline in smoking rates.
# Item 155: Correct
#
# Processing item 156/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 2, The new public transport system provided an effective alternative to car use, easing traffic congestion.
# Item 156: Incorrect
#
# Processing item 157/1000...
# Generated Response: Hypothesis 1: The rise in energy conservation awareness led to more mindful energy usage by residents, complementing the impact of energy-efficient appliances.
# Correct Hypothesis: Hypothesis: 1, The rise in energy conservation awareness led to more mindful energy usage by residents, complementing the impact of energy-efficient appliances.
# Item 157: Correct
#
# Processing item 158/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, The decrease in urban pollution contributed to a healthier environment, indirectly affecting community wellbeing.
# Item 158: Correct
#
# Processing item 159/1000...
# Generated Response: Hypothesis 1: The celebrity's influence changed teenagers' perceptions more significantly than expected.
# Correct Hypothesis: Hypothesis: 1, The celebrity's influence changed teenagers' perceptions more significantly than expected.
# Item 159: Correct
#
# Processing item 160/1000...
# Generated Response: Hypothesis 3: Advancements in solar panel technology made renewable energy more cost-effective.
# Correct Hypothesis: Hypothesis: 3, Advancements in solar panel technology made renewable energy more cost-effective.
# Item 160: Correct
#
# Processing item 161/1000...
# Generated Response: Hypothesis 3: The rise in neighborhood associations fostered a stronger sense of community, encouraging more engagement.
# Correct Hypothesis: Hypothesis: 3, The rise in neighborhood associations fostered a stronger sense of community, encouraging more engagement.
# Item 161: Correct
#
# Processing item 162/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, International collaboration in health science led to the sharing of knowledge and best practices, enhancing healthcare quality.
# Item 162: Correct
#
# Processing item 163/1000...
# Generated Response: Hypothesis 1: Improvements in electric vehicle technology made them more accessible, contributing to reduced pollution.
# Correct Hypothesis: Hypothesis: 1, Improvements in electric vehicle technology made them more accessible, contributing to reduced pollution.
# Item 163: Correct
#
# Processing item 164/1000...
# Generated Response: Hypothesis 1: Community-led health initiatives encouraged more communal activities and interactions, fostering cohesion.
# Correct Hypothesis: Hypothesis: 1, Community-led health initiatives encouraged more communal activities and interactions, fostering cohesion.
# Item 164: Correct
#
# Processing item 165/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, Advancements in energy storage technologies increased the efficiency and reduced the cost of renewable energy.
# Item 165: Correct
#
# Processing item 166/1000...
# Generated Response: Hypothesis 1: The recycling program was the primary reason for the decrease in landfill waste.
# Correct Hypothesis: Hypothesis: 3, The increase in community environmental awareness led to more responsible waste management practices, reducing landfill waste.
# Item 166: Incorrect
#
# Processing item 167/1000...
# Generated Response: Hypothesis 2: The global economic upturn was the primary reason for reduced unemployment.
# Correct Hypothesis: Hypothesis: 3, Renewable energy projects created new job opportunities, contributing to lower unemployment.
# Item 167: Incorrect
#
# Processing item 168/1000...
# Generated Response: Hypothesis 2: Advancements in wind and solar technology made renewable energy more feasible and efficient.
# Correct Hypothesis: Hypothesis: 2, Advancements in wind and solar technology made renewable energy more feasible and efficient.
# Item 168: Correct
#
# Processing item 169/1000...
# Generated Response: Hypothesis 3: The digital literacy program empowered more citizens to engage in tech entrepreneurship.
# Correct Hypothesis: Hypothesis: 3, The digital literacy program empowered more citizens to engage in tech entrepreneurship.
# Item 169: Correct
#
# Processing item 170/1000...
# Generated Response: Hypothesis 3: The rise in local food production was the primary reason for increased community cohesion.
# ...
# Correct Hypothesis: Hypothesis: 2, Technological advancements in solar panels made them more efficient and cost-effective, contributing to lower energy costs.
# Item 950: Correct
#
# Processing item 951/1000...
# Generated Response: Hypothesis 2: Advancements in eco-friendly building materials made sustainable construction more feasible and attractive.
# Correct Hypothesis: Hypothesis: 2, Advancements in eco-friendly building materials made sustainable construction more feasible and attractive.
# Item 951: Correct
#
# Processing item 952/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 1, International collaboration in health science led to the sharing of knowledge and best practices, enhancing healthcare quality.
# Item 952: Incorrect
#
# Processing item 953/1000...
# Generated Response: Hypothesis 3: The introduction of solar-powered public lighting provided an additional sustainable energy source, enhancing the town's lighting efficiency.
# Correct Hypothesis: Hypothesis: 3, The introduction of solar-powered public lighting provided an additional sustainable energy source, enhancing the town's lighting efficiency.
# Item 953: Correct
#
# Processing item 954/1000...
# Generated Response: Hypothesis 1: The recycling program might have inadvertently encouraged more consumption, leading to more waste.
# Correct Hypothesis: Hypothesis: 1, The recycling program might have inadvertently encouraged more consumption, leading to more waste.
# Item 954: Correct
#
# Processing item 955/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, The ban on plastic bags significantly reduced marine pollution, indirectly benefiting marine biodiversity.
# Item 955: Correct
#
# Processing item 956/1000...
# Generated Response: Hypothesis 2: The enhancement of public libraries created spaces that fostered community interaction and learning.
# Correct Hypothesis: Hypothesis: 2, The enhancement of public libraries created spaces that fostered community interaction and learning.
# Item 956: Correct
#
# Processing item 957/1000...
# Generated Response: Hypothesis 3: Advancements in mobile technology made telemedicine more accessible in rural areas.
# Correct Hypothesis: Hypothesis: 3, Advancements in mobile technology made telemedicine more accessible in rural areas.
# Item 957: Correct
#
# Processing item 958/1000...
# Generated Response: 1: The investment in high-speed internet 94; was a response to the digital revolution in industry, and these in turn caused a boost in e-ヒャー , because to gain competitity there had to carryout such as a systems. 2: Over time, each and ever faster interset9 94 the working-styles, us and the use f-n are equivalent, they system horse and could not have all the best organizationasyltem. equiring 94, that said, a significant change of efforts 94; on the other hand, its main character was a c' ' ' ' ' ' 'revspo revolutionary gun and the use of technology in communication is still only a bit if it's true bit if it's true b ' ' ' ' ' 'conditional' meaning that its main character was a ' ' ' ' ' ' ' 's history in the world of television of televisionworld of television that its main character was a t a' ' ' ' ' ' ' ' ' ' ' ' 's's' show of television that its main character was an artist a' ' ' ' ' ' ' ' ' master.
# Correct Hypothesis: Hypothesis: 3, The trend towards digital transformation enabled more businesses to adapt to e-commerce and remote working models.
# Item 958: Incorrect
#
# Processing item 959/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 1, Community safety initiatives fostered a safer environment, complementing the impact of smart street lighting.
# Item 959: Incorrect
#
# Processing item 960/1000...
# Generated Response: The public health awareness campaign was the sole factor in lifestyle-related diseases.
# Correct Hypothesis: Hypothesis: 3, The increase in fitness facilities provided more opportunities for regular exercise, contributing to better public health.
# Item 960: Incorrect
#
# Processing item 961/1000...
# Generated Response: Hypothesis 1: Advancements in green technology made solar panels and wind turbines more efficient and cost-effective.
# Correct Hypothesis: Hypothesis: 1, Advancements in green technology made solar panels and wind turbines more efficient and cost-effective.
# Item 961: Correct
#
# Processing item 962/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, The reduction in the use of private vehicles led to lower emissions, complementing the effect of electric buses.
# Item 962: Correct
#
# Processing item 963/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, Advancements in renewable energy technology made it more efficient and cost-effective, encouraging the shift from fossil fuels.
# Item 963: Correct
#
# Processing item 964/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, The rise in neighborhood associations fostered a stronger sense of community, encouraging more engagement.
# Item 964: Correct
#
# Processing item 965/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, The reduction in the use of private vehicles led to lower emissions, complementing the effect of electric buses.
# Item 965: Correct
#
# Processing item 966/1000...
# Generated Response: Hypothesis 3: Health education programs were the primary reason for the improvement in public health.
# Correct Hypothesis: Hypothesis: 2, Advancements in medical technology provided more effective treatment options, contributing to better health outcomes.
# Item 966: Incorrect
#
# Processing item 967/1000...
# Generated Response: Hypothesis 2: The jellyfish blooms could have deterred tourists despite the beach's accolades.
# Correct Hypothesis: Hypothesis: 2, The jellyfish blooms could have deterred tourists despite the beach's accolades.
# Item 967: Correct
#
# Processing item 968/1000...
# Generated Response: Hypothesis 1: Advancements in internet technology made online learning more accessible and appealing.
# Correct Hypothesis: Hypothesis: 1, Advancements in internet technology made online learning more accessible and appealing.
# Item 968: Correct
#
# Processing item 969/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, Community-led health initiatives encouraged more communal activities and interactions, fostering cohesion.
# Item 969: Correct
#
# Processing item 970/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, Investment in nuclear energy led to reduced reliance on coal, thereby improving air quality.
# Item 970: Correct
#
# Processing item 971/1000...
# Generated Response: Hypothesis 1: The global trend in digital transformation created a conducive environment for online business growth.
# Correct Hypothesis: Hypothesis: 1, The global trend in digital transformation created a conducive environment for online business growth.
# Item 971: Correct
#
# Processing item 972/1000...
# Generated Response: Hypothesis 3: The investment in high-speed internet infrastructure was the primary reason for the boost in e-commerce and remote working.
# Correct Hypothesis: Hypothesis: 2, The trend towards digital transformation enabled more businesses to adapt to e-commerce and remote working models.
# Item 972: Incorrect
#
# Processing item 973/1000...
# Generated Response: Hypothesis 1: The increase in urban green spaces provided residents with a natural, calming environment, contributing to stress reduction.
# Correct Hypothesis: Hypothesis: 1, The increase in urban green spaces provided residents with a natural, calming environment, contributing to stress reduction.
# Item 973: Correct
#
# Processing item 974/1000...
# Generated Response: Hypothesis 3: New policy promoting neighborhood initiatives encouraged residents to participate more in local activities, including urban gardening.
# Correct Hypothesis: Hypothesis: 3, New policy promoting neighborhood initiatives encouraged residents to participate more in local activities, including urban gardening.
# Item 974: Correct
#
# Processing item 975/1000...
# Generated Response: hypothesis 2
# Correct Hypothesis: Hypothesis: 3, Community safety initiatives fostered a safer environment, complementing the impact of smart street lighting.
# Item 975: Incorrect
#
# Processing item 976/1000...
# Generated Response: Hypothesis 1: The initiative to digitize public services was the sole factor in improving government efficiency.
# Correct Hypothesis: Hypothesis: 3, The rise in digital literacy enabled citizens to better engage with digital services, improving overall efficiency.
# Item 976: Incorrect
#
# Processing item 977/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 3, Advancements in weather forecasting technology allowed for better preparation and response to potential flooding.
# Item 977: Incorrect
#
# Processing item 978/1000...
# Generated Response: Hypothesis 3: Advancements in energy-saving technologies complemented the green building standards, enhancing overall energy efficiency.
# Correct Hypothesis: Hypothesis: 3, Advancements in energy-saving technologies complemented the green building standards, enhancing overall energy efficiency.
# Item 978: Correct
#
# Processing item 979/1000...
# Generated Response: Hypothesis 2
# Correct Hypothesis: Hypothesis: 2, Investment in nuclear energy led to reduced reliance on coal, thereby improving air quality.
# Item 979: Correct
#
# Processing item 980/1000...
# Generated Response: Hypothesis 3: The anti-littering campaign was the primary factor for the reduction in urban pollution.
# Correct Hypothesis: Hypothesis: 2, Stricter waste management regulations effectively reduced the amount of litter and pollution in the city.
# Item 980: Incorrect
#
# Processing item 981/1000...
# Generated Response: Hypothesis 1: Increased library funding was the sole reason for the improvement in literacy rates.
# Correct Hypothesis: Hypothesis: 2, New educational technologies made learning more accessible and engaging, contributing to higher literacy rates.
# Item 981: Incorrect
#
# Processing item 982/1000...
# Generated Response: Hypothesis 2: Improvements in dietary habits contributed to better overall health, complementing the availability of sports facilities.
# Correct Hypothesis: Hypothesis: 2, Improvements in dietary habits contributed to better overall health, complementing the availability of sports facilities.
# Item 982: Correct
#
# Processing item 983/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, Noise reduction policies created a more serene urban environment, contributing to lower stress levels.
# Item 983: Correct
#
# Processing item 984/1000...
# Generated Response: Hypothesis 1: The rise in e-cigarette popularity offered an alternative to traditional smoking, contributing to the decrease.
# Correct Hypothesis: Hypothesis: 1, The rise in e-cigarette popularity offered an alternative to traditional smoking, contributing to the decrease.
# Item 984: Correct
#
# Processing item 985/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, The recycling program might have inadvertently encouraged more consumption, leading to more waste.
# Item 985: Correct
#
# Processing item 986/1000...
# Generated Response: Hypothesis 3: Mandatory coding classes equipped youth with the skills to participate in the burgeoning global tech industry.
# Correct Hypothesis: Hypothesis: 3, Mandatory coding classes equipped youth with the skills to participate in the burgeoning global tech industry.
# Item 986: Correct
#
# Processing item 987/1000...
# Generated Response: Hypothesis 1: Energy-efficient appliances were the primary reason for the reduction in energy consumption.
# Correct Hypothesis: Hypothesis: 3, The rise in energy conservation awareness led to more mindful energy usage by residents, complementing the impact of energy-efficient appliances.
# Item 987: Incorrect
#
# Processing item 988/1000...
# Generated Response: Hypothesis 3: Free Wi-Fi in public areas attracted more entrepreneurs and tourists, boosting local business growth.
# Correct Hypothesis: Hypothesis: 3, Free Wi-Fi in public areas attracted more entrepreneurs and tourists, boosting local business growth.
# Item 988: Correct
#
# Processing item 989/1000...
# Generated Response: Hypothesis 1
# Correct Hypothesis: Hypothesis: 1, The road improved access to educational resources and opportunities.
# Item 989: Correct
#
# Processing item 990/1000...
# Generated Response: Hypothesis 1: Advancements in energy storage technologies increased the efficiency and reduced the cost of renewable energy.
# Correct Hypothesis: Hypothesis: 1, Advancements in energy storage technologies increased the efficiency and reduced the cost of renewable energy.
# Item 990: Correct
#
# Processing item 991/1000...
# Generated Response: Hypothesis 3
# Correct Hypothesis: Hypothesis: 3, The trend towards remote working reduced the number of vehicles on the road, aiding in easing traffic conditions.
# Item 991: Correct
#
# Processing item 992/1000...
# Generated Response: Hypothesis 3: The reduction in plastic waste improved natural habitats, indirectly benefiting wildlife.
# Correct Hypothesis: Hypothesis: 3, The reduction in plastic waste improved natural habitats, indirectly benefiting wildlife.
# Item 992: Correct
#
# Processing item 993/1000...
# Generated Response: Hypothesis 1: The country's investment in science education was the primary driver of the surge in research and innovation.
# Correct Hypothesis: Hypothesis: 2, Private sector funding provided additional resources, boosting research and innovation.
# Item 993: Incorrect
#
# Processing item 994/1000...
# Generated Response: Hypothesis 2: Improvements in internet infrastructure made online filing more accessible, contributing to its efficiency.
# Correct Hypothesis: Hypothesis: 2, Improvements in internet infrastructure made online filing more accessible, contributing to its efficiency.
# Item 994: Correct
#
# Processing item 995/1000...
# Generated Response: Hypothesis 2: Public art projects provided a constructive outlet for youth, contributing to lower crime rates.
# Correct Hypothesis: Hypothesis: 2, Public art projects provided a constructive outlet for youth, contributing to lower crime rates.
# Item 995: Correct
#
# Processing item 996/1000...
# Generated Response: Hypothesis 1: The public health awareness campaign was the sole factor in decreasing lifestyle-related diseases.
# Correct Hypothesis: Hypothesis: 2, The increase in fitness facilities provided more opportunities for regular exercise, contributing to better public health.
# Item 996: Incorrect
#
# Processing item 997/1000...
# Generated Response: Hypothesis 1: Advancements in solar panel technology made renewable energy more cost-effective.
# Correct Hypothesis: Hypothesis: 1, Advancements in solar panel technology made renewable energy more cost-effective.
# Item 997: Correct
#
# Processing item 998/1000...
# Generated Response: Hypothesis 1: The recycling program was the primary reason for the decrease in landfill waste.
# Correct Hypothesis: Hypothesis: 3, The increase in community environmental awareness led to more responsible waste management practices, reducing landfill waste.
# Item 998: Incorrect
#
# Processing item 999/1000...
# Generated Response: Hypothesis 3: Advancements in renewable energy technology made it more efficient and cost-effective, encouraging the shift from fossil fuels.
# Correct Hypothesis: Hypothesis: 3, Advancements in renewable energy technology made it more efficient and cost-effective, encouraging the shift from fossil fuels.
# Item 999: Correct
#
# Processing item 1000/1000...
# Generated Response: Hypothesis 3: Stricter traffic laws led to more cautious driving behaviors, contributing to fewer accidents.
# Correct Hypothesis: Hypothesis: 3, Stricter traffic laws led to more cautious driving behaviors, contributing to fewer accidents.
# Item 1000: Correct
#
# Processed Items: 999, Skipped Items: 1
# Accuracy: 76.48%
# 0.7647647647647647
# Accuracy with Gemini: 76.476%
# Responses saved.
# Accuracy: 76.476%
# sklearn Accuracy: 76.476%
# F1: 77.159%
# Precision: 81.963%
# Recall: 76.476%
