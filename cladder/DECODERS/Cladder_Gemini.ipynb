# %%
# !pip install -q -U google-generativeai

# %%
import pathlib
import textwrap

import google.generativeai as genai

# Used to securely store your API key
from google.colab import userdata

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
GOOGLE_API_KEY='AIzaSyD8NxtHgBgTa8FxXvjv3kEDjR24RlaM4Is'
genai.configure(api_key=GOOGLE_API_KEY)
gemini_model = genai.GenerativeModel('gemini-pro')

# %%
import pandas as pd
import json

dataset = pd.read_csv("data_full_v1.csv")
dataset['ground_truth'] = dataset.apply(lambda row: 1 if row['label']=='yes' else 0, axis=1)
dataset = dataset.sample(frac=1)
dataset = json.loads(dataset.to_json(orient ='records'))

# %%
# Format the COPA query for the GPT-3.5 Turbo model
def format_query(item):
    # return f"{item['prompt']}. Yes or No?"
    # return f"{item['prompt']}. No or Yes?"
    return f"{item['prompt']}"

  # return f"{item['prompt']}. Output only single digit 0 or 1. 0 for no and 1 for yes. Output should have only single digit. Do not output any text other than a single digit"

format_query(dataset[0])
# Out:
# 'Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships: Zory has a direct effect on zuph and glimx. Jyka has a direct effect on zuph. Zuph has a direct effect on glimx. Zory is unobserved.\nThe overall probability of zuph is 43%. The probability of not zuph and glimx is 27%. The probability of zuph and glimx is 17%.\nIs the chance of glimx smaller when observing zuph?'

# %%
def query_gemini(query, model):
    chat = model.start_chat(history=[])
    response = chat.send_message(query)
    return response.text

# %%
query_gemini(format_query(dataset[0]), gemini_model)
# Out:
# 'Yes, the chance of glimx is smaller when observing zuph.\n\nGiven the probability of Zuph (P(Z)) is 43%, the probability of not zuph (¬Z) is 1 - P(Z) = 57%.\n\nThe probability of glimx given zuph (P(G|Z)) can be calculated as follows:\nP(G|Z) = P(Z and G) / P(Z)\n= 0.17 / 0.43\n= 0.4\n\nThe probability of glimx given not zuph (P(G|¬Z)) can be calculated as follows:\nP(G|¬Z) = P(¬Z and G) / P(¬Z)\n= (0.27 - 0.17) / 0.57\n= 0.175\n\nTherefore, the chance of glimx when observing zuph (P(G|Z) = 0.4) is smaller than the chance of glimx when not observing zuph (P(G|¬Z) = 0.175).'

# %%
from tenacity import retry, stop_after_attempt, wait_random_exponential, RetryError
import re

correct_count = 0
processed_items = 0
processed = []
failed_items = []
y_true = []
y_pred = []

# Evaluate the accuracy of GPT-3.5 Turbo on the COPA dataset
@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(1))
def evaluate_accuracy(item):
      global correct_count
      query = format_query(item)

      # print('may1')

      chat = gemini_model.start_chat(history=[])
      # print('may2')
      # print('query ', query)
      generated_text = chat.send_message(query).text
      # print('may3')

      generated_text = generated_text.removeprefix(query).lower()
      # print('may4')

      # print(generated_text)
      generated_text = [w for w in re.split('\W', generated_text) if w]
#       print(generated_text)
      # generated_text = ''.join(filter(str.isalnum, generated_text)).split()

      if (('yes' in generated_text) or ('yes.' in generated_text)) and ((not 'no' in generated_text) and (not 'no.' in generated_text)):
        response = 1
      elif (('no' in generated_text) or ('no.' in generated_text)) and ((not 'yes' in generated_text) and (not 'yes.' in generated_text)):
        response = 0
      else:
#         print(query)
        # print(response)
        print(generated_text)
        raise Exception("failure")

      # response = pred[-1]
      print(response)
      # print(item['ground_truth'])
      correct_hypothesis = ((int(response) == item['ground_truth'])==True)
      y_true.append(item['ground_truth'])
      y_pred.append(int(response))
      # print(correct_hypothesis)
      correct_count += correct_hypothesis
      print("correct_count is ", correct_count)
      # print("completed\n")


# Evaluate accuracy
def evaluate_accuracy_wrapper(data):
      global correct_count
      global processed_items
      global failed_items
      for item in data:
          try:
              evaluate_accuracy(item)
              processed_items = processed_items +1
              processed.append(item)
          except RetryError as e:
              print("failed")
              failed_items.append(item)
          if processed_items==1000:
            break
          if processed_items%10==0:
            print('processed_items ', processed_items)
      print("correct_count in wrapper is ", correct_count)
      return correct_count / len(data)

accuracy = evaluate_accuracy_wrapper(dataset)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# 1
# correct_count is  1
# 1
# correct_count is  1
# 1
# correct_count is  2
# ['the', 'information', 'provided', 'does', 'not', 'allow', 'for', 'a', 'definitive', 'conclusion', 'on', 'whether', 'yupt', 'negatively', 'affects', 'muvq', 'through', 'zupj', 'and', 'xyfo', 'the', 'provided', 'information', 'establishes', 'that', 'yupt', 'has', 'a', 'direct', 'effect', 'on', 'xyfo', 'and', 'zupj', 'zupj', 'has', 'a', 'direct', 'effect', 'on', 'muvq', 'and', 'xyfo', 'has', 'a', 'direct', 'effect', 'on', 'muvq', 'however', 'it', 'does', 'not', 'specify', 'the', 'nature', 'or', 'strength', 'of', 'these', 'effects', 'nor', 'does', 'it', 'provide', 'any', 'information', 'about', 'the', 'potential', 'indirect', 'effects', 'of', 'yupt', 'on', 'muvq', 'through', 'zupj', 'and', 'xyfo', 'additionally', 'the', 'provided', 'information', 'does', 'not', 'account', 'for', 'the', 'potential', 'influence', 'of', 'other', 'factors', 'that', 'may', 'also', 'affect', 'the', 'probability', 'of', 'muvq', 'therefore', 'it', 'is', 'not', 'possible', 'to', 'determine', 'from', 'the', 'given', 'information', 'whether', 'yupt', 'negatively', 'affects', 'muvq', 'through', 'zupj', 'and', 'xyfo']
# failed
# 1
# correct_count is  2
# ['yes', 'smoking', 'negatively', 'affects', 'lung', 'cancer', 'through', 'tar', 'deposit', 'from', 'the', 'given', 'information', 'we', 'can', 'construct', 'the', 'following', 'table', 'smoking', 'tar', 'deposit', 'lung', 'cancer', 'probability', 'no', 'no', 'no', '0', '41', '1', '0', '09', '0', '3731', 'no', 'no', 'yes', '0', '41', '0', '09', '0', '0369', 'no', 'yes', 'no', '1', '0', '41', '1', '0', '87', '0', '0469', 'no', 'yes', 'yes', '1', '0', '41', '0', '87', '0', '4431', 'yes', 'no', 'no', '0', '44', '1', '0', '09', '0', '3996', 'yes', 'no', 'yes', '0', '44', '0', '09', '0', '0396', 'yes', 'yes', 'no', '1', '0', '44', '1', '0', '87', '0', '0273', 'yes', 'yes', 'yes', '1', '0', '44', '0', '87', '0', '4835', 'we', 'can', 'see', 'that', 'the', 'probability', 'of', 'lung', 'cancer', 'is', 'higher', 'for', 'smokers', 'with', 'high', 'tar', 'deposit', '53', 'than', 'for', 'smokers', 'with', 'no', 'tar', 'deposit', '27', 'this', 'suggests', 'that', 'tar', 'deposit', 'is', 'a', 'mediating', 'factor', 'between', 'smoking', 'and', 'lung', 'cancer', 'to', 'further', 'confirm', 'this', 'we', 'can', 'calculate', 'the', 'probability', 'of', 'lung', 'cancer', 'for', 'smokers', 'and', 'nonsmokers', 'regardless', 'of', 'tar', 'deposit', 'p', 'lung', 'cancer', 'smoking', '0', '27', '0', '44', '0', '53', '0', '56', '0', '4284', 'p', 'lung', 'cancer', 'nonsmoking', '0', '41', '0', '91', '0', '66', '0', '09', '0', '4219', 'we', 'can', 'see', 'that', 'the', 'probability', 'of', 'lung', 'cancer', 'is', 'higher', 'for', 'smokers', 'than', 'for', 'nonsmokers', 'even', 'after', 'accounting', 'for', 'tar', 'deposit', 'this', 'provides', 'further', 'evidence', 'that', 'smoking', 'negatively', 'affects', 'lung', 'cancer', 'through', 'tar', 'deposit']
# failed
# 1
# correct_count is  3
# 1
# correct_count is  4
# 1
# correct_count is  5
# ['method', '2', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '1', 'to', 'understand', 'how', 'having', 'visited', 'england', 'affects', 'employee', 'in', 'method', '1', 'the', 'correlation', 'between', 'having', 'visited', 'england', 'and', 'employee', 'is', 'observed', 'directly', 'without', 'considering', 'the', 'potential', 'confounding', 'effect', 'of', 'director', 'this', 'means', 'that', 'any', 'observed', 'correlation', 'could', 'be', 'due', 'to', 'the', 'direct', 'effect', 'of', 'having', 'visited', 'england', 'on', 'employee', 'or', 'it', 'could', 'be', 'due', 'to', 'the', 'indirect', 'effect', 'of', 'having', 'visited', 'england', 'on', 'director', 'which', 'in', 'turn', 'affects', 'employee', 'method', '2', 'on', 'the', 'other', 'hand', 'takes', 'into', 'account', 'the', 'potential', 'confounding', 'effect', 'of', 'director', 'by', 'looking', 'at', 'the', 'correlation', 'between', 'having', 'visited', 'england', 'and', 'employee', 'case', 'by', 'case', 'according', 'to', 'director', 'this', 'allows', 'us', 'to', 'isolate', 'the', 'direct', 'effect', 'of', 'having', 'visited', 'england', 'on', 'employee', 'while', 'controlling', 'for', 'the', 'indirect', 'effect', 'mediated', 'by', 'director', 'therefore', 'method', '2', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '1', 'to', 'understand', 'how', 'having', 'visited', 'england', 'affects', 'employee', 'because', 'it', 'allows', 'us', 'to', 'control', 'for', 'the', 'potential', 'confounding', 'effect', 'of', 'director', 'and', 'isolate', 'the', 'direct', 'effect', 'of', 'having', 'visited', 'england', 'on', 'employee']
# failed
# 0
# correct_count is  5
# 1
# correct_count is  5
# 1
# correct_count is  6
# processed_items  10
# 1
# correct_count is  7
# 1
# correct_count is  7
# ['it', 'is', 'not', 'possible', 'to', 'determine', 'whether', 'eating', 'citrus', 'negatively', 'affects', 'curly', 'hair', 'through', 'vitamin', 'c', 'based', 'on', 'the', 'information', 'provided', 'the', 'provided', 'information', 'establishes', 'that', 'there', 'is', 'a', 'direct', 'effect', 'of', 'eating', 'citrus', 'on', 'vitamin', 'c', 'levels', 'and', 'a', 'direct', 'effect', 'of', 'vitamin', 'c', 'on', 'curly', 'hair', 'however', 'it', 'does', 'not', 'specify', 'the', 'nature', 'of', 'these', 'relationships', 'positive', 'or', 'negative', 'nor', 'does', 'it', 'provide', 'any', 'information', 'about', 'the', 'magnitude', 'or', 'strength', 'of', 'these', 'effects', 'additionally', 'the', 'probabilities', 'of', 'curly', 'hair', 'for', 'patients', 'consuming', 'and', 'not', 'consuming', 'citrus', 'are', 'given', 'but', 'these', 'probabilities', 'alone', 'do', 'not', 'allow', 'us', 'to', 'determine', 'the', 'causal', 'relationship', 'between', 'citrus', 'consumption', 'vitamin', 'c', 'and', 'curly', 'hair', 'without', 'further', 'information', 'about', 'the', 'specific', 'nature', 'and', 'strength', 'of', 'the', 'relationships', 'between', 'these', 'variables', 'it', 'is', 'not', 'possible', 'to', 'conclude', 'whether', 'eating', 'citrus', 'negatively', 'affects', 'curly', 'hair', 'through', 'vitamin', 'c']
# failed
# 1
# correct_count is  8
# 0
# correct_count is  8
# 1
# correct_count is  9
# 1
# correct_count is  9
# 0
# correct_count is  10
# 1
# correct_count is  10
# ['not', 'necessarily', 'swoy', 'has', 'a', 'direct', 'effect', 'on', 'rixq', 'and', 'xevu', 'zuph', 'has', 'a', 'direct', 'effect', 'on', 'xevu', 'swoy', 'or', 'zuph', 'causes', 'xevu', 'the', 'individual', 'is', 'not', 'swoy', 'from', 'the', 'above', 'conditions', 'we', 'know', 'that', 'swoy', 'causes', 'rixq', 'and', 'zuph', 'causes', 'xevu', 'we', 'also', 'know', 'that', 'the', 'individual', 'is', 'not', 'swoy', 'therefore', 'we', 'can', 'conclude', 'that', 'the', 'individual', 'is', 'not', 'rixq', 'however', 'we', 'cannot', 'conclude', 'whether', 'the', 'individual', 'is', 'xevu', 'or', 'not', 'this', 'is', 'because', 'we', 'do', 'not', 'know', 'whether', 'zuph', 'is', 'the', 'only', 'cause', 'of', 'xevu', 'or', 'if', 'there', 'are', 'other', 'unmentioned', 'factors', 'that', 'can', 'also', 'cause', 'xevu', 'therefore', 'the', 'answer', 'is', 'not', 'necessarily']
# failed
# 1
# correct_count is  11
# 1
# correct_count is  11
# processed_items  20
# 1
# correct_count is  11
# ['not', 'enough', 'information', 'is', 'provided', 'to', 'determine', 'whether', 'an', 'individual', 'is', 'gyzp', 'if', 'not', 'xevo', 'instead', 'of', 'xevo', 'we', 'know', 'that', 'tijw', 'causes', 'xevo', 'and', 'xevo', 'does', 'not', 'cause', 'tijv', 'however', 'we', 'do', 'not', 'know', 'the', 'relationship', 'between', 'tijv', 'and', 'xevo', 'it', 'is', 'possible', 'that', 'xevo', 'is', 'a', 'necessary', 'condition', 'for', 'tijv', 'or', 'that', 'tijv', 'is', 'a', 'necessary', 'condition', 'for', 'xevo', 'without', 'this', 'information', 'we', 'cannot', 'determine', 'whether', 'the', 'absence', 'of', 'xevo', 'would', 'lead', 'to', 'the', 'absence', 'of', 'tijv', 'additionally', 'we', 'know', 'that', 'tijw', 'and', 'tijv', 'cause', 'gyzp', 'however', 'we', 'do', 'not', 'know', 'the', 'relationship', 'between', 'xevo', 'and', 'gyzp', 'it', 'is', 'possible', 'that', 'xevo', 'is', 'a', 'necessary', 'condition', 'for', 'gyzp', 'or', 'that', 'gyzp', 'is', 'a', 'necessary', 'condition', 'for', 'xevo', 'without', 'this', 'information', 'we', 'cannot', 'determine', 'whether', 'the', 'absence', 'of', 'xevo', 'would', 'lead', 'to', 'the', 'absence', 'of', 'gyzp', 'therefore', 'we', 'cannot', 'conclude', 'whether', 'an', 'individual', 'is', 'gyzp', 'if', 'not', 'xevo', 'instead', 'of', 'xevo']
# failed
# 1
# correct_count is  12
# 1
# correct_count is  12
# 0
# correct_count is  13
# 0
# correct_count is  14
# ['yes', 'vaccination', 'causes', 'having', 'smallpox', 'and', 'no', 'vaccine', 'reaction', 'having', 'smallpox', 'or', 'severe', 'vaccination', 'reaction', 'causes', 'smallpox', 'survival', 'so', 'we', 'can', 'conclude', 'that', 'vaccination', 'causes', 'smallpox', 'survival', 'lack', 'of', 'vaccination', 'does', 'not', 'cause', 'smallpox', 'vaccination', 'causes', 'having', 'smallpox', 'so', 'lack', 'of', 'vaccination', 'causes', 'not', 'having', 'smallpox', 'having', 'smallpox', 'or', 'severe', 'vaccination', 'reaction', 'causes', 'smallpox', 'survival', 'so', 'we', 'can', 'conclude', 'that', 'lack', 'of', 'vaccination', 'causes', 'smallpox', 'survival', 'comparing', 'the', 'two', 'we', 'can', 'extrapolate', 'that', 'in', 'this', 'hypothetical', 'world', 'vaccination', 'and', 'lack', 'of', 'vaccination', 'both', 'cause', 'smallpox', 'survival']
# failed
# 0
# correct_count is  14
# ['the', 'question', 'and', 'the', 'information', 'provided', 'do', 'not', 'allow', 'for', 'a', 'meaningful', 'answer', 'the', 'probability', 'of', 'the', 'prisoner', 's', 'death', 'is', 'solely', 'determined', 'by', 'whether', 'the', 'captain', 'orders', 'the', 'release', 'or', 'execution', 'of', 'the', 'prisoner', 'and', 'is', 'not', 'influenced', 'by', 'hypothetical', 'scenarios', 'where', 'the', 'captain', 'had', 'given', 'a', 'different', 'order']
# failed
# ['yes', 'freckles', 'are', 'more', 'likely', 'than', 'no', 'freckles', 'overall', 'let', 's', 'be', 'the', 'event', 'of', 'smoking', 'and', 'f', 'be', 'the', 'event', 'of', 'having', 'freckles', 'p', 's', '0', '93', 'p', 's', '1', 'p', 's', '1', '0', '93', '0', '07', 'p', 'f', 's', '0', '66', 'p', 'f', 's', '1', 'p', 'f', 's', '1', '0', '66', '0', '34', 'p', 'f', 's', '0', '44', 'p', 'f', 's', '1', 'p', 'f', 's', '1', '0', '44', '0', '56', 'using', 'the', 'law', 'of', 'total', 'probability', 'we', 'can', 'find', 'the', 'overall', 'probability', 'of', 'freckles', 'p', 'f', 'p', 'f', 's', 'p', 's', 'p', 'f', 's', 'p', 's', '0', '66', '0', '93', '0', '44', '0', '07', '0', '6138', '0', '0308', '0', '6446', 'therefore', 'the', 'overall', 'probability', 'of', 'freckles', 'is', '64', '46', 'which', 'is', 'greater', 'than', 'the', 'probability', 'of', 'no', 'freckles']
# failed
# 1
# correct_count is  15
# ['the', 'provided', 'information', 'does', 'not', 'allow', 'us', 'to', 'determine', 'whether', 'vaccination', 'status', 'negatively', 'affects', 'smallpox', 'survival', 'through', 'getting', 'smallpox', 'and', 'vaccination', 'reaction', 'the', 'conclusion', 'cannot', 'be', 'drawn', 'because', 'we', 'do', 'not', 'know', 'the', 'probabilities', 'of', 'getting', 'smallpox', 'and', 'vaccination', 'reaction', 'for', 'vaccinated', 'and', 'unvaccinated', 'individuals']
# failed
# ['the', 'information', 'provided', 'does', 'not', 'allow', 'us', 'to', 'determine', 'whether', 'the', 'patient', 'would', 'not', 'recover', 'if', 'they', 'had', 'a', 'high', 'hospital', 'bill', 'instead', 'of', 'a', 'low', 'hospital', 'bill', 'we', 'know', 'that', 'age', 'has', 'a', 'direct', 'effect', 'on', 'hospital', 'costs', 'and', 'recovery', 'and', 'that', 'hospital', 'costs', 'have', 'a', 'direct', 'effect', 'on', 'recovery', 'this', 'means', 'that', 'older', 'patients', 'tend', 'to', 'have', 'higher', 'hospital', 'bills', 'and', 'longer', 'recovery', 'times', 'however', 'we', 'do', 'not', 'know', 'the', 'specific', 'relationship', 'between', 'hospital', 'costs', 'and', 'recovery', 'or', 'how', 'much', 'of', 'an', 'impact', 'a', 'high', 'hospital', 'bill', 'would', 'have', 'on', 'a', 'patient', 's', 'recovery', 'additionally', 'we', 'know', 'that', 'old', 'age', 'or', 'high', 'hospital', 'bill', 'causes', 'recovery', 'this', 'means', 'that', 'either', 'being', 'old', 'or', 'having', 'a', 'high', 'hospital', 'bill', 'can', 'lead', 'to', 'recovery', 'however', 'we', 'do', 'not', 'know', 'which', 'of', 'these', 'factors', 'is', 'more', 'likely', 'to', 'cause', 'recovery', 'or', 'how', 'the', 'two', 'factors', 'interact', 'overall', 'the', 'information', 'provided', 'is', 'not', 'sufficient', 'to', 'determine', 'whether', 'the', 'patient', 'would', 'not', 'recover', 'if', 'they', 'had', 'a', 'high', 'hospital', 'bill', 'instead', 'of', 'a', 'low', 'hospital', 'bill']
# failed
# ['method', '2', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '1', 'to', 'understand', 'how', 'rixq', 'affects', 'xevu', 'method', '1', 'looks', 'at', 'the', 'correlation', 'between', 'rixq', 'and', 'xevu', 'in', 'general', 'without', 'considering', 'the', 'effect', 'of', 'swoy', 'this', 'could', 'lead', 'to', 'misleading', 'results', 'as', 'the', 'correlation', 'between', 'rixq', 'and', 'xevu', 'may', 'be', 'different', 'depending', 'on', 'the', 'value', 'of', 'swoy', 'method', '2', 'on', 'the', 'other', 'hand', 'looks', 'at', 'the', 'correlation', 'between', 'rixq', 'and', 'xevu', 'case', 'by', 'case', 'according', 'to', 'swoy', 'this', 'allows', 'us', 'to', 'see', 'how', 'the', 'effect', 'of', 'rixq', 'on', 'xevu', 'changes', 'as', 'swoy', 'changes', 'this', 'provides', 'a', 'more', 'accurate', 'picture', 'of', 'the', 'relationship', 'between', 'rixq', 'and', 'xevu', 'and', 'allows', 'us', 'to', 'better', 'understand', 'how', 'rixq', 'affects', 'xevu']
# failed
# ['method', '2', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '1', 'to', 'understand', 'how', 'zuph', 'affects', 'uvzi', 'in', 'method', '1', 'we', 'look', 'directly', 'at', 'the', 'correlation', 'between', 'zuph', 'and', 'uvzi', 'in', 'general', 'however', 'this', 'correlation', 'may', 'be', 'confounded', 'by', 'the', 'effect', 'of', 'vubr', 'on', 'uvzi', 'this', 'is', 'because', 'vubr', 'has', 'a', 'direct', 'effect', 'on', 'both', 'wibl', 'and', 'uvzi', 'and', 'wibl', 'has', 'a', 'direct', 'effect', 'on', 'uvzi', 'therefore', 'any', 'correlation', 'between', 'zuph', 'and', 'uvzi', 'could', 'be', 'due', 'to', 'the', 'effect', 'of', 'vubr', 'rather', 'than', 'the', 'effect', 'of', 'zuph', 'in', 'method', '2', 'we', 'look', 'at', 'the', 'correlation', 'between', 'zuph', 'and', 'uvzi', 'case', 'by', 'case', 'according', 'to', 'wibl', 'this', 'allows', 'us', 'to', 'control', 'for', 'the', 'effect', 'of', 'vubr', 'because', 'vubr', 'is', 'unobserved', 'by', 'looking', 'at', 'the', 'correlation', 'between', 'zuph', 'and', 'uvzi', 'only', 'in', 'cases', 'where', 'wibl', 'is', 'held', 'constant', 'we', 'can', 'be', 'more', 'confident', 'that', 'any', 'correlation', 'between', 'zuph', 'and', 'uvzi', 'is', 'due', 'to', 'the', 'effect', 'of', 'zuph', 'rather', 'than', 'the', 'effect', 'of', 'vubr', 'therefore', 'method', '2', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '1', 'to', 'understand', 'how', 'zuph', 'affects', 'uvzi']
# failed
# ['it', 'is', 'not', 'possible', 'to', 'determine', 'whether', 'parents', 'intelligence', 'would', 'negatively', 'affect', 'child', 's', 'intelligence', 'if', 'we', 'disregard', 'the', 'mediation', 'effect', 'through', 'parents', 'social', 'status', 'based', 'on', 'the', 'information', 'provided']
# failed
# ['method', '2', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '1', 'to', 'understand', 'how', 'yupt', 'affects', 'muvq', 'method', '1', 'examines', 'the', 'correlation', 'between', 'yupt', 'and', 'muvq', 'without', 'considering', 'the', 'effect', 'of', 'zupj', 'however', 'since', 'zupj', 'also', 'has', 'a', 'direct', 'effect', 'on', 'muvq', 'this', 'method', 'may', 'not', 'provide', 'an', 'accurate', 'understanding', 'of', 'the', 'relationship', 'between', 'yupt', 'and', 'muvq', 'method', '2', 'on', 'the', 'other', 'hand', 'takes', 'into', 'account', 'the', 'effect', 'of', 'zupj', 'by', 'examining', 'the', 'correlation', 'between', 'yupt', 'and', 'muvq', 'for', 'different', 'values', 'of', 'zupj', 'this', 'allows', 'us', 'to', 'isolate', 'the', 'effect', 'of', 'yupt', 'on', 'muvq', 'while', 'controlling', 'for', 'the', 'effect', 'of', 'zupj', 'providing', 'a', 'more', 'accurate', 'picture', 'of', 'the', 'relationship', 'between', 'the', 'two', 'variables', 'therefore', 'method', '2', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '1', 'to', 'understand', 'how', 'yupt', 'affects', 'muvq']
# failed
# 1
# correct_count is  15
# 0
# correct_count is  16
# 1
# correct_count is  16
# processed_items  30
# 1
# correct_count is  16
# ['method', '2', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '1', 'to', 'understand', 'how', 'having', 'a', 'sister', 'affects', 'prisoner', 'method', '1', 'looks', 'at', 'the', 'correlation', 'between', 'having', 'a', 'sister', 'and', 'being', 'a', 'prisoner', 'in', 'general', 'this', 'method', 'does', 'not', 'take', 'into', 'account', 'the', 'fact', 'that', 'the', 'relationship', 'between', 'having', 'a', 'sister', 'and', 'being', 'a', 'prisoner', 'may', 'vary', 'depending', 'on', 'the', 'private', 'circumstances', 'of', 'the', 'individual', 'for', 'example', 'having', 'a', 'sister', 'may', 'have', 'a', 'different', 'effect', 'on', 'a', 'prisoner', 'who', 'grew', 'up', 'in', 'a', 'loving', 'and', 'supportive', 'home', 'than', 'on', 'a', 'prisoner', 'who', 'grew', 'up', 'in', 'an', 'abusive', 'or', 'neglectful', 'home', 'method', '2', 'looks', 'at', 'the', 'correlation', 'between', 'having', 'a', 'sister', 'and', 'being', 'a', 'prisoner', 'case', 'by', 'case', 'according', 'to', 'the', 'private', 'circumstances', 'of', 'the', 'individual', 'this', 'method', 'allows', 'us', 'to', 'see', 'how', 'the', 'relationship', 'between', 'having', 'a', 'sister', 'and', 'being', 'a', 'prisoner', 'varies', 'depending', 'on', 'the', 'individual', 's', 'private', 'circumstances', 'this', 'information', 'can', 'be', 'used', 'to', 'develop', 'more', 'targeted', 'interventions', 'to', 'help', 'prisoners', 'who', 'are', 'struggling', 'with', 'the', 'challenges', 'of', 'incarceration']
# failed
# ['it', 'is', 'not', 'possible', 'to', 'determine', 'whether', 'the', 'person', 'would', 'have', 'lung', 'cancer', 'if', 'they', 'had', 'a', 'nonsmoking', 'gene', 'instead', 'of', 'a', 'smoking', 'gene', 'based', 'on', 'the', 'provided', 'information', 'the', 'information', 'states', 'that', 'smoking', 'gene', 'or', 'high', 'pollution', 'causes', 'smoking', 'and', 'smoking', 'gene', 'or', 'high', 'pollution', 'or', 'smoking', 'causes', 'lung', 'cancer', 'however', 'it', 'does', 'not', 'specify', 'the', 'strength', 'or', 'direction', 'of', 'these', 'relationships', 'it', 'is', 'possible', 'that', 'the', 'effect', 'of', 'smoking', 'gene', 'on', 'lung', 'cancer', 'is', 'stronger', 'than', 'the', 'effect', 'of', 'pollution', 'on', 'lung', 'cancer', 'or', 'vice', 'versa', 'additionally', 'the', 'information', 'does', 'not', 'specify', 'the', 'probability', 'of', 'lung', 'cancer', 'given', 'smoking', 'gene', 'and', 'low', 'pollution', 'or', 'the', 'probability', 'of', 'lung', 'cancer', 'given', 'nonsmoking', 'gene', 'and', 'low', 'pollution', 'therefore', 'it', 'is', 'not', 'possible', 'to', 'determine', 'whether', 'the', 'person', 'would', 'have', 'lung', 'cancer', 'if', 'they', 'had', 'a', 'nonsmoking', 'gene', 'instead', 'of', 'a', 'smoking', 'gene']
# failed
# ['it', 'is', 'not', 'possible', 'to', 'determine', 'whether', 'high', 'salary', 'is', 'less', 'likely', 'than', 'low', 'salary', 'overall', 'with', 'the', 'given', 'information', 'the', 'information', 'provided', 'does', 'not', 'include', 'the', 'probability', 'of', 'high', 'salary', 'or', 'low', 'salary', 'without', 'this', 'information', 'it', 'is', 'not', 'possible', 'to', 'compare', 'the', 'likelihood', 'of', 'high', 'salary', 'and', 'low', 'salary']
# failed
# 0
# correct_count is  17
# 1
# correct_count is  18
# 1
# correct_count is  18
# ['method', '2', 'is', 'more', 'correct', 'to', 'use', 'to', 'understand', 'how', 'jyka', 'affects', 'lirg', 'method', '1', 'looks', 'at', 'the', 'correlation', 'between', 'jyka', 'and', 'lirg', 'in', 'general', 'without', 'considering', 'the', 'role', 'of', 'hwax', 'this', 'means', 'that', 'any', 'correlation', 'found', 'between', 'jyka', 'and', 'lirg', 'could', 'be', 'due', 'to', 'a', 'third', 'factor', 'that', 'affects', 'both', 'jyka', 'and', 'lirg', 'rather', 'than', 'a', 'direct', 'causal', 'relationship', 'between', 'the', 'two', 'method', '2', 'on', 'the', 'other', 'hand', 'looks', 'at', 'the', 'correlation', 'between', 'jyka', 'and', 'lirg', 'case', 'by', 'case', 'according', 'to', 'hwax', 'this', 'allows', 'us', 'to', 'see', 'how', 'the', 'relationship', 'between', 'jyka', 'and', 'lirg', 'changes', 'depending', 'on', 'the', 'level', 'of', 'hwax', 'this', 'information', 'can', 'help', 'us', 'to', 'determine', 'whether', 'there', 'is', 'a', 'direct', 'causal', 'relationship', 'between', 'jyka', 'and', 'lirg', 'or', 'whether', 'the', 'relationship', 'is', 'mediated', 'by', 'hwax', 'for', 'example', 'if', 'we', 'find', 'that', 'the', 'correlation', 'between', 'jyka', 'and', 'lirg', 'is', 'positive', 'when', 'hwax', 'is', 'high', 'but', 'negative', 'when', 'hwax', 'is', 'low', 'this', 'would', 'suggest', 'that', 'the', 'relationship', 'between', 'jyka', 'and', 'lirg', 'is', 'mediated', 'by', 'hwax', 'in', 'this', 'case', 'hwax', 'would', 'be', 'the', 'confounding', 'factor', 'that', 'is', 'responsible', 'for', 'the', 'correlation', 'between', 'jyka', 'and', 'lirg', 'therefore', 'method', '2', 'is', 'the', 'more', 'correct', 'method', 'to', 'use', 'to', 'understand', 'how', 'jyka', 'affects', 'lirg', 'as', 'it', 'allows', 'us', 'to', 'control', 'for', 'the', 'confounding', 'effects', 'of', 'hwax']
# failed
# 1
# correct_count is  19
# 1
# correct_count is  20
# ['information', 'provided', 'does', 'not', 'allow', 'us', 'to', 'determine', 'the', 'overall', 'probability', 'of', 'recovery', 'for', 'patients', 'paying', 'a', 'high', 'or', 'low', 'hospital', 'bill', 'the', 'overall', 'probability', 'of', 'recovery', 'depends', 'on', 'the', 'probability', 'of', 'being', 'young', 'or', 'old', 'and', 'the', 'probability', 'of', 'paying', 'a', 'high', 'or', 'low', 'hospital', 'bill', 'for', 'each', 'age', 'group', 'without', 'knowing', 'these', 'probabilities', 'we', 'cannot', 'determine', 'the', 'overall', 'probability', 'of', 'recovery', 'for', 'patients', 'paying', 'a', 'high', 'or', 'low', 'hospital', 'bill']
# failed
# ['given', 'the', 'probability', 'of', 'nonsmoking', 'mother', 'and', 'normal', 'infant', 'birth', 'weight', 'is', '6', 'and', 'the', 'probability', 'of', 'smoking', 'mother', 'and', 'normal', 'infant', 'birth', 'weight', 'is', '17', 'the', 'probability', 'of', 'normal', 'infant', 'birth', 'weight', 'when', 'observing', 'smoking', 'mother', 'is', '17', '17', '40', '17', '57', '0', '3', 'the', 'probability', 'of', 'normal', 'infant', 'birth', 'weight', 'when', 'observing', 'nonsmoking', 'mother', 'is', '6', '6', '60', '6', '66', '0', '09', 'therefore', 'the', 'chance', 'of', 'normal', 'infant', 'birth', 'weight', 'is', 'larger', 'when', 'observing', 'nonsmoking', 'mother']
# failed
# ['yes', 'it', 'would', 'be', 'less', 'likely', 'to', 'see', 'recovery', 'if', 'the', 'patient', 'had', 'received', 'no', 'treatment', 'for', 'patients', 'receiving', 'treatment', 'the', 'probability', 'of', 'recovery', 'is', '64', 'if', 'they', 'are', 'not', 'male', 'and', '8', 'if', 'they', 'are', 'male', 'this', 'means', 'that', 'the', 'overall', 'probability', 'of', 'recovery', 'for', 'patients', 'receiving', 'treatment', 'is', '0', '51', '0', '64', '0', '49', '0', '08', '36', '64', '3', '92', '40', '56', 'for', 'patients', 'not', 'receiving', 'treatment', 'the', 'probability', 'of', 'recovery', 'is', '96', 'if', 'they', 'are', 'not', 'male', 'and', '38', 'if', 'they', 'are', 'male', 'this', 'means', 'that', 'the', 'overall', 'probability', 'of', 'recovery', 'for', 'patients', 'not', 'receiving', 'treatment', 'is', '0', '51', '0', '96', '0', '49', '0', '38', '49', '08', '18', '62', '67', '7', 'therefore', 'the', 'overall', 'probability', 'of', 'recovery', 'is', 'higher', 'for', 'patients', 'not', 'receiving', 'treatment', '67', '7', 'than', 'for', 'patients', 'receiving', 'treatment', '40', '56', 'this', 'means', 'that', 'it', 'would', 'be', 'less', 'likely', 'to', 'see', 'recovery', 'if', 'the', 'patient', 'had', 'received', 'treatment']
# failed
# 1
# correct_count is  20
# failed
# 0
# correct_count is  20
# 1
# correct_count is  20
# 1
# correct_count is  20
# processed_items  40
# 1
# correct_count is  20
# 1
# correct_count is  20
# 1
# correct_count is  21
# ['method', '2', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '1', 'to', 'understand', 'how', 'kwox', 'affects', 'kwoz', 'method', '1', 'which', 'simply', 'looks', 'at', 'the', 'overall', 'correlation', 'between', 'kwox', 'and', 'kwoz', 'does', 'not', 'take', 'into', 'account', 'the', 'potential', 'confounding', 'effect', 'of', 'muvy', 'since', 'muvy', 'has', 'a', 'direct', 'effect', 'on', 'both', 'kwox', 'and', 'kwoz', 'any', 'observed', 'correlation', 'between', 'kwox', 'and', 'kwoz', 'could', 'be', 'due', 'to', 'the', 'influence', 'of', 'muvy', 'rather', 'than', 'a', 'direct', 'causal', 'relationship', 'between', 'kwox', 'and', 'kwoz', 'method', '2', 'on', 'the', 'other', 'hand', 'examines', 'the', 'relationship', 'between', 'kwox', 'and', 'kwoz', 'in', 'different', 'levels', 'of', 'muvy', 'by', 'doing', 'so', 'it', 'can', 'help', 'to', 'isolate', 'the', 'direct', 'effect', 'of', 'kwox', 'on', 'kwoz', 'from', 'the', 'confounding', 'effect', 'of', 'muvy', 'for', 'example', 'if', 'the', 'correlation', 'between', 'kwox', 'and', 'kwoz', 'is', 'stronger', 'in', 'cases', 'where', 'muvy', 'is', 'high', 'than', 'in', 'cases', 'where', 'muvy', 'is', 'low', 'this', 'would', 'suggest', 'that', 'the', 'relationship', 'between', 'kwox', 'and', 'kwoz', 'is', 'indeed', 'being', 'mediated', 'by', 'muvy', 'therefore', 'method', '2', 'is', 'a', 'more', 'appropriate', 'method', 'for', 'understanding', 'the', 'causal', 'relationship', 'between', 'kwox', 'and', 'kwoz', 'as', 'it', 'takes', 'into', 'account', 'the', 'potential', 'confounding', 'effect', 'of', 'muvy', 'and', 'allows', 'for', 'a', 'more', 'precise', 'examination', 'of', 'the', 'direct', 'relationship', 'between', 'the', 'two', 'variables']
# failed
# ['method', '2', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '1', 'to', 'understand', 'how', 'playing', 'card', 'games', 'affect', 'lifespan', 'method', '1', 'would', 'only', 'show', 'a', 'correlation', 'between', 'playing', 'card', 'games', 'and', 'lifespan', 'but', 'it', 'would', 'not', 'be', 'able', 'to', 'account', 'for', 'the', 'confounding', 'effect', 'of', 'diabetes', 'this', 'means', 'that', 'the', 'observed', 'correlation', 'between', 'playing', 'card', 'games', 'and', 'lifespan', 'could', 'be', 'due', 'to', 'the', 'fact', 'that', 'people', 'who', 'play', 'card', 'games', 'are', 'also', 'more', 'likely', 'to', 'have', 'diabetes', 'which', 'is', 'itself', 'associated', 'with', 'a', 'shorter', 'lifespan', 'method', '2', 'on', 'the', 'other', 'hand', 'would', 'be', 'able', 'to', 'control', 'for', 'the', 'confounding', 'effect', 'of', 'diabetes', 'by', 'looking', 'at', 'the', 'correlation', 'between', 'playing', 'card', 'games', 'and', 'lifespan', 'separately', 'for', 'people', 'with', 'and', 'without', 'diabetes', 'this', 'would', 'allow', 'us', 'to', 'see', 'if', 'there', 'is', 'a', 'direct', 'effect', 'of', 'playing', 'card', 'games', 'on', 'lifespan', 'independent', 'of', 'the', 'effect', 'of', 'diabetes', 'therefore', 'method', '2', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '1', 'to', 'understand', 'how', 'playing', 'card', 'games', 'affect', 'lifespan']
# failed
# 1
# correct_count is  22
# 0
# correct_count is  23
# 1
# correct_count is  23
# ['insufficient', 'information', 'to', 'determine', 'the', 'given', 'conditions', 'do', 'not', 'provide', 'any', 'information', 'about', 'the', 'relationship', 'between', 'not', 'drinking', 'coffee', 'and', 'the', 'alarm', 'ringing', 'the', 'next', 'morning', 'therefore', 'it', 'is', 'impossible', 'to', 'determine', 'whether', 'the', 'alarm', 'would', 'ring', 'or', 'not']
# failed
# ['yes', 'it', 'would', 'be', 'less', 'likely', 'to', 'see', 'being', 'allergic', 'to', 'peanuts', 'if', 'the', 'person', 'had', 'been', 'a', 'nonsmoker', 'for', 'smokers', 'and', 'with', 'no', 'tar', 'deposit', 'the', 'probability', 'of', 'being', 'allergic', 'to', 'peanuts', 'is', '42', 'for', 'nonsmokers', 'and', 'with', 'no', 'tar', 'deposit', 'the', 'probability', 'of', 'being', 'allergic', 'to', 'peanuts', 'is', '34', 'therefore', 'it', 'is', 'less', 'likely', 'to', 'see', 'being', 'allergic', 'to', 'peanuts', 'if', 'the', 'person', 'had', 'been', 'a', 'nonsmoker']
# failed
# 0
# correct_count is  23
# 1
# correct_count is  23
# 1
# correct_count is  23
# ['method', '2', 'is', 'more', 'correct', 'to', 'use', 'to', 'understand', 'how', 'husband', 'affects', 'alarm', 'clock', 'in', 'method', '1', 'we', 'are', 'looking', 'at', 'the', 'overall', 'correlation', 'between', 'husband', 'and', 'alarm', 'clock', 'without', 'considering', 'the', 'role', 'of', 'wife', 'this', 'means', 'that', 'any', 'correlation', 'we', 'find', 'could', 'be', 'due', 'to', 'factors', 'other', 'than', 'the', 'direct', 'effect', 'of', 'husband', 'on', 'alarm', 'clock', 'however', 'method', '2', 'allows', 'us', 'to', 'look', 'at', 'the', 'relationship', 'between', 'husband', 'and', 'alarm', 'clock', 'in', 'specific', 'cases', 'according', 'to', 'the', 'wife', 'this', 'means', 'that', 'we', 'can', 'control', 'for', 'the', 'effect', 'of', 'wife', 'and', 'see', 'how', 'husband', 'directly', 'affects', 'alarm', 'clock', 'therefore', 'method', '2', 'is', 'more', 'likely', 'to', 'give', 'us', 'a', 'more', 'accurate', 'understanding', 'of', 'the', 'relationship', 'between', 'husband', 'and', 'alarm', 'clock']
# failed
# 1
# correct_count is  23
# processed_items  50
# ['method', '2', 'is', 'more', 'correct', 'to', 'understand', 'how', 'encouragement', 'level', 'affects', 'exam', 'score', 'method', '1', 'only', 'looks', 'at', 'the', 'overall', 'correlation', 'between', 'encouragement', 'level', 'and', 'exam', 'score', 'without', 'considering', 'the', 'potential', 'moderating', 'effect', 'of', 'studying', 'habit', 'this', 'means', 'that', 'method', '1', 'cannot', 'account', 'for', 'the', 'possibility', 'that', 'the', 'relationship', 'between', 'encouragement', 'level', 'and', 'exam', 'score', 'may', 'vary', 'depending', 'on', 'the', 'individual', 's', 'studying', 'habit', 'for', 'example', 'it', 'is', 'possible', 'that', 'encouragement', 'may', 'have', 'a', 'stronger', 'effect', 'on', 'exam', 'score', 'for', 'individuals', 'with', 'poor', 'studying', 'habits', 'compared', 'to', 'individuals', 'with', 'good', 'studying', 'habits', 'method', '2', 'addresses', 'this', 'issue', 'by', 'examining', 'the', 'correlation', 'between', 'encouragement', 'level', 'and', 'exam', 'score', 'separately', 'for', 'different', 'levels', 'of', 'studying', 'habit', 'this', 'allows', 'us', 'to', 'see', 'how', 'the', 'relationship', 'between', 'encouragement', 'level', 'and', 'exam', 'score', 'changes', 'depending', 'on', 'studying', 'habit', 'and', 'thus', 'provides', 'a', 'more', 'nuanced', 'understanding', 'of', 'the', 'effect', 'of', 'encouragement', 'level', 'on', 'exam', 'score']
# failed
# processed_items  50
# 0
# correct_count is  23
# ['method', '2', 'is', 'more', 'correct', 'to', 'use', 'in', 'understanding', 'how', 'the', 'captain', 'affects', 'prisoner', 'in', 'method', '1', 'we', 'are', 'looking', 'at', 'the', 'overall', 'correlation', 'between', 'the', 'captain', 'and', 'the', 'prisoner', 'without', 'considering', 'the', 'mediating', 'effects', 'of', 'the', 'private', 'and', 'the', 'corporal', 'this', 'approach', 'is', 'problematic', 'because', 'it', 'assumes', 'that', 'the', 'captain', 's', 'effect', 'on', 'the', 'prisoner', 'is', 'direct', 'and', 'unmediated', 'however', 'the', 'conditions', 'given', 'in', 'the', 'hypothetical', 'world', 'suggest', 'that', 'the', 'captain', 's', 'effect', 'on', 'the', 'prisoner', 'is', 'indirect', 'and', 'mediated', 'through', 'the', 'private', 'and', 'the', 'corporal', 'method', '2', 'on', 'the', 'other', 'hand', 'takes', 'into', 'account', 'the', 'mediating', 'effects', 'of', 'the', 'private', 'and', 'the', 'corporal', 'by', 'examining', 'the', 'correlation', 'between', 'the', 'captain', 'and', 'the', 'prisoner', 'case', 'by', 'case', 'according', 'to', 'the', 'private', 'we', 'can', 'better', 'understand', 'how', 'the', 'captain', 's', 'effect', 'on', 'the', 'prisoner', 'is', 'transmitted', 'through', 'the', 'private', 'this', 'approach', 'allows', 'us', 'to', 'identify', 'the', 'specific', 'mechanisms', 'through', 'which', 'the', 'captain', 's', 'actions', 'and', 'decisions', 'impact', 'the', 'prisoner', 's', 'outcomes', 'therefore', 'method', '2', 'is', 'more', 'correct', 'to', 'use', 'in', 'understanding', 'how', 'the', 'captain', 'affects', 'prisoner', 'because', 'it', 'takes', 'into', 'account', 'the', 'mediating', 'effects', 'of', 'the', 'private', 'and', 'the', 'corporal', 'which', 'are', 'specified', 'in', 'the', 'conditions', 'of', 'the', 'hypothetical', 'world']
# failed
# 1
# correct_count is  24
# ['it', 'is', 'more', 'correct', 'to', 'use', 'method', '1', 'than', 'method', '2', 'to', 'understand', 'how', 'yupt', 'affects', 'muvq', 'method', '1', 'involves', 'examining', 'the', 'correlation', 'between', 'yupt', 'and', 'muvq', 'on', 'a', 'case', 'by', 'case', 'basis', 'by', 'considering', 'the', 'value', 'of', 'zupj', 'this', 'approach', 'allows', 'for', 'a', 'more', 'precise', 'analysis', 'of', 'the', 'relationship', 'between', 'yupt', 'and', 'muvq', 'as', 'it', 'takes', 'into', 'account', 'the', 'moderating', 'effect', 'of', 'zupj', 'by', 'looking', 'at', 'the', 'correlation', 'between', 'yupt', 'and', 'muvq', 'across', 'different', 'values', 'of', 'zupj', 'researchers', 'can', 'determine', 'how', 'the', 'strength', 'and', 'direction', 'of', 'the', 'relationship', 'changes', 'depending', 'on', 'the', 'level', 'of', 'zupj', 'this', 'information', 'can', 'provide', 'valuable', 'insights', 'into', 'the', 'nature', 'of', 'the', 'relationship', 'between', 'yupt', 'and', 'muvq', 'and', 'help', 'identify', 'any', 'potential', 'confounding', 'factors', 'on', 'the', 'other', 'hand', 'method', '2', 'involves', 'looking', 'directly', 'at', 'the', 'correlation', 'between', 'yupt', 'and', 'muvq', 'in', 'general', 'without', 'considering', 'the', 'value', 'of', 'zupj', 'this', 'approach', 'does', 'not', 'take', 'into', 'account', 'the', 'moderating', 'effect', 'of', 'zupj', 'and', 'may', 'lead', 'to', 'misleading', 'conclusions', 'about', 'the', 'relationship', 'between', 'yupt', 'and', 'muvq', 'by', 'not', 'examining', 'the', 'correlation', 'between', 'yupt', 'and', 'muvq', 'in', 'the', 'context', 'of', 'zupj', 'researchers', 'may', 'overlook', 'important', 'information', 'that', 'could', 'help', 'them', 'better', 'understand', 'the', 'relationship', 'between', 'these', 'two', 'variables', 'therefore', 'method', '1', 'is', 'a', 'more', 'appropriate', 'and', 'accurate', 'approach', 'to', 'understand', 'how', 'yupt', 'affects', 'muvq', 'as', 'it', 'allows', 'for', 'a', 'more', 'comprehensive', 'analysis', 'of', 'the', 'relationship', 'between', 'these', 'two', 'variables', 'by', 'considering', 'the', 'moderating', 'effect', 'of', 'zupj']
# failed
# 0
# correct_count is  25
# 1
# correct_count is  25
# 1
# correct_count is  25
# ['method', '2', 'is', 'more', 'correct', 'to', 'use', 'to', 'understand', 'how', 'eating', 'citrus', 'affects', 'curly', 'hair', 'method', '1', 'only', 'looks', 'at', 'the', 'direct', 'correlation', 'between', 'eating', 'citrus', 'and', 'curly', 'hair', 'in', 'general', 'this', 'method', 'does', 'not', 'take', 'into', 'account', 'the', 'role', 'of', 'vitamin', 'c', 'which', 'is', 'a', 'necessary', 'intermediate', 'step', 'in', 'the', 'causal', 'relationship', 'between', 'eating', 'citrus', 'and', 'curly', 'hair', 'as', 'a', 'result', 'method', '1', 'is', 'likely', 'to', 'produce', 'misleading', 'or', 'inaccurate', 'results', 'method', '2', 'on', 'the', 'other', 'hand', 'looks', 'at', 'the', 'correlation', 'between', 'eating', 'citrus', 'and', 'curly', 'hair', 'case', 'by', 'case', 'according', 'to', 'vitamin', 'c', 'levels', 'this', 'method', 'takes', 'into', 'account', 'the', 'role', 'of', 'vitamin', 'c', 'as', 'an', 'intermediate', 'step', 'in', 'the', 'causal', 'relationship', 'between', 'eating', 'citrus', 'and', 'curly', 'hair', 'as', 'a', 'result', 'method', '2', 'is', 'more', 'likely', 'to', 'produce', 'accurate', 'and', 'reliable', 'results', 'in', 'general', 'when', 'trying', 'to', 'understand', 'the', 'relationship', 'between', 'two', 'variables', 'it', 'is', 'important', 'to', 'consider', 'all', 'of', 'the', 'relevant', 'factors', 'and', 'causal', 'relationships', 'that', 'may', 'be', 'involved', 'this', 'will', 'help', 'to', 'ensure', 'that', 'the', 'results', 'of', 'the', 'study', 'are', 'accurate', 'and', 'reliable']
# failed
# 1
# correct_count is  26
# ['method', '2', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '1', 'to', 'understand', 'how', 'maternal', 'smoking', 'status', 'affects', 'infant', 's', 'birth', 'weight', 'method', '1', 'attempts', 'to', 'control', 'for', 'unobserved', 'confounders', 'by', 'looking', 'at', 'how', 'maternal', 'smoking', 'status', 'correlates', 'with', 'infant', 's', 'birth', 'weight', 'case', 'by', 'case', 'according', 'to', 'unobserved', 'confounders', 'however', 'this', 'method', 'is', 'not', 'effective', 'because', 'unobserved', 'confounders', 'are', 'unobserved', 'meaning', 'that', 'we', 'cannot', 'measure', 'or', 'control', 'for', 'them', 'as', 'a', 'result', 'method', '1', 'is', 'likely', 'to', 'produce', 'biased', 'results', 'method', '2', 'on', 'the', 'other', 'hand', 'looks', 'directly', 'at', 'how', 'maternal', 'smoking', 'status', 'correlates', 'with', 'infant', 's', 'birth', 'weight', 'in', 'general', 'this', 'method', 'does', 'not', 'attempt', 'to', 'control', 'for', 'unobserved', 'confounders', 'but', 'it', 'is', 'still', 'more', 'likely', 'to', 'produce', 'unbiased', 'results', 'than', 'method', '1', 'this', 'is', 'because', 'the', 'unobserved', 'confounders', 'are', 'likely', 'to', 'be', 'randomly', 'distributed', 'across', 'the', 'population', 'so', 'their', 'effects', 'will', 'cancel', 'each', 'other', 'out', 'when', 'we', 'look', 'at', 'the', 'data', 'in', 'aggregate', 'for', 'example', 'consider', 'the', 'following', 'scenario', 'suppose', 'that', 'there', 'are', 'two', 'unobserved', 'confounders', 'maternal', 'age', 'and', 'socioeconomic', 'status', 'maternal', 'age', 'is', 'positively', 'correlated', 'with', 'infant', 's', 'birth', 'weight', 'while', 'socioeconomic', 'status', 'is', 'negatively', 'correlated', 'with', 'infant', 's', 'birth', 'weight', 'if', 'we', 'were', 'to', 'use', 'method', '1', 'we', 'would', 'find', 'that', 'the', 'correlation', 'between', 'maternal', 'smoking', 'status', 'and', 'infant', 's', 'birth', 'weight', 'is', 'positive', 'in', 'some', 'cases', 'and', 'negative', 'in', 'other', 'cases', 'depending', 'on', 'the', 'values', 'of', 'the', 'unobserved', 'confounders', 'this', 'would', 'make', 'it', 'difficult', 'to', 'draw', 'any', 'conclusions', 'about', 'the', 'true', 'effect', 'of', 'maternal', 'smoking', 'status', 'on', 'infant', 's', 'birth', 'weight', 'however', 'if', 'we', 'were', 'to', 'use', 'method', '2', 'we', 'would', 'find', 'that', 'the', 'correlation', 'between', 'maternal', 'smoking', 'status', 'and', 'infant', 's', 'birth', 'weight', 'is', 'negative', 'overall', 'this', 'is', 'because', 'the', 'positive', 'effect', 'of', 'maternal', 'age', 'is', 'canceled', 'out', 'by', 'the', 'negative', 'effect', 'of', 'socioeconomic', 'status', 'as', 'a', 'result', 'method', '2', 'would', 'allow', 'us', 'to', 'correctly', 'conclude', 'that', 'maternal', 'smoking', 'status', 'has', 'a', 'negative', 'effect', 'on', 'infant', 's', 'birth', 'weight']
# failed
# ['method', '1', 'is', 'more', 'correct', 'to', 'understand', 'how', 'pexu', 'affects', 'rukz', 'method', '1', 'takes', 'into', 'account', 'the', 'direct', 'effect', 'of', 'kraz', 'on', 'both', 'pexu', 'and', 'rukz', 'which', 'allows', 'us', 'to', 'isolate', 'the', 'effect', 'of', 'pexu', 'on', 'rukz', 'while', 'controlling', 'for', 'the', 'confounding', 'effect', 'of', 'kraz', 'by', 'looking', 'at', 'how', 'pexu', 'correlates', 'with', 'rukz', 'case', 'by', 'case', 'according', 'to', 'kraz', 'we', 'can', 'better', 'understand', 'the', 'specific', 'relationship', 'between', 'these', 'two', 'variables', 'and', 'how', 'it', 'is', 'influenced', 'by', 'kraz', 'method', '2', 'on', 'the', 'other', 'hand', 'does', 'not', 'take', 'into', 'account', 'the', 'direct', 'effect', 'of', 'kraz', 'on', 'rukz', 'as', 'a', 'result', 'the', 'observed', 'correlation', 'between', 'pexu', 'and', 'rukz', 'may', 'be', 'confounded', 'by', 'the', 'effect', 'of', 'kraz', 'this', 'means', 'that', 'the', 'correlation', 'between', 'pexu', 'and', 'rukz', 'may', 'not', 'accurately', 'reflect', 'the', 'true', 'relationship', 'between', 'these', 'two', 'variables', 'as', 'it', 'may', 'be', 'influenced', 'by', 'the', 'unobserved', 'variable', 'kraz', 'therefore', 'method', '1', 'is', 'more', 'correct', 'to', 'use', 'to', 'understand', 'how', 'pexu', 'affects', 'rukz', 'because', 'it', 'allows', 'us', 'to', 'isolate', 'the', 'effect', 'of', 'pexu', 'on', 'rukz', 'while', 'controlling', 'for', 'the', 'confounding', 'effect', 'of', 'kraz']
# failed
# 1
# correct_count is  27
# 0
# correct_count is  28
# 1
# correct_count is  29
# failed
# 1
# correct_count is  30
# processed_items  60
# ['it', 'is', 'more', 'correct', 'to', 'use', 'method', '2', 'to', 'understand', 'how', 'eating', 'citrus', 'affects', 'curly', 'hair', 'method', '1', 'only', 'looks', 'at', 'the', 'direct', 'correlation', 'between', 'eating', 'citrus', 'and', 'curly', 'hair', 'in', 'general', 'without', 'accounting', 'for', 'the', 'role', 'of', 'vitamin', 'c', 'this', 'method', 'may', 'lead', 'to', 'incorrect', 'conclusions', 'if', 'there', 'are', 'other', 'factors', 'that', 'influence', 'the', 'relationship', 'between', 'citrus', 'consumption', 'and', 'curly', 'hair', 'for', 'example', 'if', 'people', 'who', 'eat', 'citrus', 'also', 'tend', 'to', 'have', 'a', 'diet', 'rich', 'in', 'other', 'nutrients', 'that', 'promote', 'curly', 'hair', 'then', 'method', '1', 'could', 'mistakenly', 'attribute', 'the', 'effect', 'of', 'these', 'other', 'nutrients', 'to', 'citrus', 'consumption', 'method', '2', 'on', 'the', 'other', 'hand', 'takes', 'into', 'account', 'the', 'role', 'of', 'vitamin', 'c', 'as', 'a', 'mediator', 'between', 'citrus', 'consumption', 'and', 'curly', 'hair', 'by', 'examining', 'the', 'correlation', 'between', 'citrus', 'consumption', 'vitamin', 'c', 'levels', 'and', 'curly', 'hair', 'case', 'by', 'case', 'method', '2', 'can', 'more', 'accurately', 'determine', 'the', 'causal', 'relationship', 'between', 'citrus', 'consumption', 'and', 'curly', 'hair', 'this', 'method', 'is', 'less', 'likely', 'to', 'be', 'confounded', 'by', 'other', 'factors', 'as', 'it', 'controls', 'for', 'the', 'effect', 'of', 'vitamin', 'c', 'therefore', 'method', '2', 'is', 'the', 'more', 'correct', 'approach', 'to', 'understanding', 'the', 'relationship', 'between', 'citrus', 'consumption', 'and', 'curly', 'hair']
# failed
# processed_items  60
# 0
# correct_count is  30
# 0
# correct_count is  31
# ['it', 'is', 'more', 'correct', 'to', 'use', 'method', '1', 'than', 'method', '2', 'to', 'understand', 'how', 'yupt', 'affects', 'muvq', 'because', 'method', '1', 'takes', 'into', 'account', 'the', 'direct', 'effect', 'of', 'xyfo', 'on', 'muvq', 'and', 'allows', 'for', 'the', 'examination', 'of', 'the', 'relationship', 'between', 'yupt', 'and', 'muvq', 'while', 'considering', 'the', 'influence', 'of', 'xyfo', 'here', 's', 'why', 'method', '1', 'is', 'more', 'correct', '1', 'direct', 'effects', 'method', '1', 'considers', 'the', 'direct', 'effect', 'of', 'xyfo', 'on', 'muvq', 'as', 'stated', 'in', 'the', 'given', 'conditions', 'xyfo', 'has', 'a', 'direct', 'impact', 'on', 'muvq', 'so', 'disregarding', 'this', 'effect', 'would', 'lead', 'to', 'an', 'incomplete', 'analysis', 'of', 'the', 'relationship', 'between', 'yupt', 'and', 'muvq', '2', 'isolating', 'the', 'impact', 'of', 'yupt', 'method', '1', 'isolates', 'the', 'impact', 'of', 'yupt', 'on', 'muvq', 'by', 'examining', 'the', 'correlation', 'between', 'these', 'two', 'variables', 'separately', 'for', 'different', 'values', 'of', 'xyfo', 'by', 'doing', 'so', 'method', '1', 'helps', 'determine', 'the', 'specific', 'influence', 'of', 'yupt', 'on', 'muvq', 'while', 'accounting', 'for', 'the', 'varying', 'influence', 'of', 'xyfo', '3', 'controlling', 'for', 'xyfo', 's', 'influence', 'by', 'considering', 'xyfo', 'as', 'a', 'variable', 'in', 'the', 'analysis', 'method', '1', 'controls', 'for', 'its', 'effect', 'on', 'the', 'relationship', 'between', 'yupt', 'and', 'muvq', 'this', 'approach', 'allows', 'researchers', 'to', 'draw', 'more', 'accurate', 'conclusions', 'about', 'the', 'causal', 'relationship', 'between', 'yupt', 'and', 'muvq', 'as', 'it', 'minimizes', 'the', 'confounding', 'effect', 'of', 'xyfo', 'method', '2', 'on', 'the', 'other', 'hand', 'looks', 'at', 'the', 'overall', 'correlation', 'between', 'yupt', 'and', 'muvq', 'without', 'considering', 'the', 'direct', 'effect', 'of', 'xyfo', 'this', 'approach', 'does', 'not', 'account', 'for', 'the', 'influence', 'of', 'xyfo', 'and', 'may', 'lead', 'to', 'misleading', 'conclusions', 'about', 'the', 'relationship', 'between', 'yupt', 'and', 'muvq', 'therefore', 'using', 'method', '1', 'which', 'takes', 'into', 'account', 'the', 'direct', 'effect', 'of', 'xyfo', 'and', 'examines', 'the', 'relationship', 'between', 'yupt', 'and', 'muvq', 'separately', 'for', 'different', 'values', 'of', 'xyfo', 'is', 'more', 'correct', 'in', 'understanding', 'how', 'yupt', 'affects', 'muvq']
# failed
# 1
# correct_count is  32
# 1
# correct_count is  33
# 1
# correct_count is  34
# 1
# correct_count is  35
# 0
# correct_count is  35
# 0
# correct_count is  36
# 1
# correct_count is  37
# 1
# correct_count is  38
# processed_items  70
# ['yes', 'it', 'would', 'be', 'more', 'likely', 'to', 'see', 'being', 'allergic', 'to', 'peanuts', 'if', 'the', 'patient', 'had', 'received', 'no', 'treatment', 'to', 'determine', 'if', 'it', 'is', 'more', 'likely', 'to', 'see', 'being', 'allergic', 'to', 'peanuts', 'if', 'the', 'patient', 'had', 'received', 'no', 'treatment', 'we', 'can', 'calculate', 'the', 'probabilities', 'of', 'being', 'allergic', 'to', 'peanuts', 'for', 'patients', 'receiving', 'treatment', 'and', 'patients', 'not', 'receiving', 'treatment', 'for', 'patients', 'receiving', 'treatment', 'p', 'peanut', 'allergy', 'treatment', 'p', 'peanut', 'allergy', 'and', 'treatment', 'p', 'treatment', '0', '71', '0', '46', '0', '03', '0', '54', '0', '71', '0', '46', '0', '03', '0', '54', '0', '263', 'for', 'patients', 'not', 'receiving', 'treatment', 'p', 'peanut', 'allergy', 'no', 'treatment', 'p', 'peanut', 'allergy', 'and', 'no', 'treatment', 'p', 'no', 'treatment', '0', '84', '0', '46', '0', '21', '0', '54', '0', '84', '0', '46', '0', '21', '0', '54', '0', '691', 'comparing', 'these', 'probabilities', 'we', 'can', 'see', 'that', 'the', 'probability', 'of', 'being', 'allergic', 'to', 'peanuts', 'is', 'lower', 'for', 'patients', 'receiving', 'treatment', '0', '263', 'than', 'for', 'patients', 'not', 'receiving', 'treatment', '0', '691', 'therefore', 'it', 'would', 'be', 'more', 'likely', 'to', 'see', 'being', 'allergic', 'to', 'peanuts', 'if', 'the', 'patient', 'had', 'received', 'no', 'treatment']
# failed
# ...
# failed
# 1
# correct_count is  579
# 1
# correct_count is  580
# 0
# correct_count is  580
# 1
# correct_count is  581
# ['not', 'enough', 'information', 'is', 'provided', 'to', 'determine', 'whether', 'the', 'forest', 'would', 'burn', 'down', 'if', 'the', 'camper', 'did', 'not', 'light', 'a', 'match', 'instead', 'of', 'lighting', 'a', 'match', 'the', 'provided', 'information', 'states', 'that', 'the', 'camper', 'lighting', 'a', 'match', 'and', 'the', 'chain', 'smoker', 'lighting', 'a', 'match', 'causes', 'the', 'forest', 'on', 'fire', 'and', 'that', 'the', 'chain', 'smoker', 'lights', 'a', 'match', 'however', 'it', 'does', 'not', 'specify', 'whether', 'the', 'forest', 'would', 'burn', 'down', 'if', 'only', 'the', 'camper', 'lit', 'a', 'match', 'or', 'if', 'only', 'the', 'chain', 'smoker', 'lit', 'a', 'match', 'additionally', 'it', 'does', 'not', 'provide', 'any', 'information', 'about', 'other', 'potential', 'factors', 'that', 'could', 'contribute', 'to', 'the', 'forest', 'burning', 'down', 'such', 'as', 'weather', 'conditions', 'the', 'presence', 'of', 'other', 'flammable', 'materials', 'or', 'the', 'actions', 'of', 'other', 'individuals', 'therefore', 'it', 'is', 'not', 'possible', 'to', 'determine', 'whether', 'the', 'forest', 'would', 'burn', 'down', 'if', 'the', 'camper', 'did', 'not', 'light', 'a', 'match', 'instead', 'of', 'lighting', 'a', 'match', 'based', 'on', 'the', 'provided', 'information']
# failed
# ['yes', 'smoking', 'will', 'increase', 'the', 'chance', 'of', 'freckles', 'let', 's', 'calculate', 'conditional', 'probabilities', 'first', 'p', 'high', 'tar', 'deposit', 'smoking', '29', 'p', 'high', 'tar', 'deposit', 'no', 'smoking', '74', 'p', 'freckles', 'high', 'tar', 'deposit', 'smoking', '58', 'p', 'freckles', 'no', 'tar', 'deposit', 'smoking', '84', 'p', 'freckles', 'high', 'tar', 'deposit', 'no', 'smoking', '59', 'p', 'freckles', 'no', 'tar', 'deposit', 'no', 'smoking', '85', 'p', 'smoking', '63', 'p', 'no', 'smoking', '1', 'p', 'smoking', '37', 'now', 'we', 'can', 'calculate', 'the', 'probability', 'of', 'freckles', 'given', 'smoking', 'and', 'not', 'smoking', 'p', 'freckles', 'smoking', 'p', 'high', 'tar', 'deposit', 'freckles', 'smoking', 'p', 'no', 'tar', 'deposit', 'freckles', 'smoking', 'p', 'freckles', 'high', 'tar', 'deposit', 'smoking', 'p', 'high', 'tar', 'deposit', 'smoking', 'p', 'freckles', 'no', 'tar', 'deposit', 'smoking', 'p', 'no', 'tar', 'deposit', 'smoking', '58', '29', '84', '71', '17', '59', '76', 'p', 'freckles', 'no', 'smoking', 'p', 'high', 'tar', 'deposit', 'freckles', 'no', 'smoking', 'p', 'no', 'tar', 'deposit', 'freckles', 'no', 'smoking', 'p', 'freckles', 'high', 'tar', 'deposit', 'no', 'smoking', 'p', 'high', 'tar', 'deposit', 'no', 'smoking', 'p', 'freckles', 'no', 'tar', 'deposit', 'no', 'smoking', 'p', 'no', 'tar', 'deposit', 'no', 'smoking', '59', '74', '85', '26', '44', '22', '66', 'therefore', 'p', 'freckles', 'smoking', 'p', 'freckles', 'no', 'smoking', '76', '66', '1', '15', 'conclusion', 'smoking', 'increases', 'the', 'chance', 'of', 'freckles', 'by', '15']
# failed
# 1
# correct_count is  582
# 1
# correct_count is  582
# ['method', '2', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '1', 'to', 'understand', 'how', 'medication', 'affects', 'heart', 'condition', 'method', '1', 'only', 'looks', 'at', 'the', 'overall', 'correlation', 'between', 'medication', 'and', 'heart', 'condition', 'without', 'considering', 'the', 'role', 'of', 'blood', 'pressure', 'this', 'means', 'that', 'any', 'observed', 'correlation', 'could', 'be', 'due', 'to', 'other', 'factors', 'besides', 'medication', 'such', 'as', 'the', 'patient', 's', 'age', 'gender', 'or', 'lifestyle', 'method', '2', 'on', 'the', 'other', 'hand', 'takes', 'into', 'account', 'the', 'fact', 'that', 'blood', 'pressure', 'is', 'a', 'direct', 'consequence', 'of', 'medication', 'and', 'also', 'has', 'a', 'direct', 'effect', 'on', 'heart', 'condition', 'by', 'looking', 'at', 'the', 'correlation', 'between', 'medication', 'and', 'heart', 'condition', 'case', 'by', 'case', 'according', 'to', 'blood', 'pressure', 'method', '2', 'can', 'help', 'to', 'identify', 'the', 'true', 'effect', 'of', 'medication', 'on', 'heart', 'condition', 'while', 'controlling', 'for', 'the', 'influence', 'of', 'blood', 'pressure', 'therefore', 'method', '2', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '1', 'to', 'understand', 'how', 'medication', 'affects', 'heart', 'condition', 'because', 'it', 'takes', 'into', 'account', 'the', 'role', 'of', 'blood', 'pressure', 'and', 'helps', 'to', 'identify', 'the', 'true', 'effect', 'of', 'medication', 'on', 'heart', 'condition']
# failed
# 1
# correct_count is  582
# ['yes', 'freckles', 'are', 'more', 'likely', 'than', 'no', 'freckles', 'overall', 'let', 's', 'break', 'down', 'the', 'probabilities', 'probability', 'of', 'freckles', 'for', 'people', 'with', 'mean', 'personalities', '50', 'probability', 'of', 'freckles', 'for', 'people', 'with', 'kind', 'personalities', '50', 'overall', 'probability', 'of', 'kindness', '43', 'overall', 'probability', 'of', 'meanness', '100', '43', '57', 'using', 'the', 'law', 'of', 'total', 'probability', 'we', 'can', 'calculate', 'the', 'overall', 'probability', 'of', 'freckles', 'p', 'freckles', 'p', 'freckles', 'mean', 'p', 'mean', 'p', 'freckles', 'kind', 'p', 'kind', 'p', 'freckles', '0', '50', '0', '57', '0', '50', '0', '43', 'p', 'freckles', '0', '285', '0', '215', 'p', 'freckles', '0', '50', 'therefore', 'the', 'overall', 'probability', 'of', 'freckles', 'is', '50', 'which', 'is', 'greater', 'than', 'the', 'overall', 'probability', 'of', 'no', 'freckles', '1', '0', '50', '0', '50', 'hence', 'freckles', 'are', 'more', 'likely', 'than', 'no', 'freckles', 'overall']
# failed
# 0
# correct_count is  583
# processed_items  990
# 1
# correct_count is  583
# 1
# correct_count is  583
# 0
# correct_count is  583
# 1
# correct_count is  584
# 1
# correct_count is  584
# ['method', '1', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '2', 'to', 'understand', 'how', 'the', 'captain', 'affects', 'prisoner', 'method', '1', 'takes', 'into', 'account', 'the', 'mediating', 'effects', 'of', 'the', 'private', 'and', 'the', 'corporal', 'while', 'method', '2', 'does', 'not', 'this', 'means', 'that', 'method', '1', 'is', 'able', 'to', 'provide', 'a', 'more', 'accurate', 'picture', 'of', 'the', 'relationship', 'between', 'the', 'captain', 'and', 'the', 'prisoner', 'for', 'example', 'method', '1', 'might', 'show', 'that', 'the', 'captain', 's', 'relationship', 'with', 'the', 'private', 'is', 'positive', 'while', 'the', 'private', 's', 'relationship', 'with', 'the', 'prisoner', 'is', 'negative', 'this', 'would', 'suggest', 'that', 'the', 'captain', 's', 'positive', 'relationship', 'with', 'the', 'private', 'is', 'outweighed', 'by', 'the', 'private', 's', 'negative', 'relationship', 'with', 'the', 'prisoner', 'resulting', 'in', 'a', 'negative', 'overall', 'relationship', 'between', 'the', 'captain', 'and', 'the', 'prisoner', 'method', '2', 'on', 'the', 'other', 'hand', 'would', 'not', 'be', 'able', 'to', 'take', 'these', 'mediating', 'effects', 'into', 'account', 'it', 'would', 'simply', 'show', 'the', 'overall', 'correlation', 'between', 'the', 'captain', 'and', 'the', 'prisoner', 'without', 'regard', 'to', 'the', 'private', 'or', 'the', 'corporal', 'this', 'could', 'lead', 'to', 'a', 'misleading', 'conclusion', 'about', 'the', 'relationship', 'between', 'the', 'captain', 'and', 'the', 'prisoner', 'in', 'general', 'it', 'is', 'important', 'to', 'consider', 'all', 'of', 'the', 'relevant', 'factors', 'when', 'trying', 'to', 'understand', 'a', 'causal', 'relationship', 'method', '1', 'does', 'this', 'by', 'taking', 'into', 'account', 'the', 'mediating', 'effects', 'of', 'the', 'private', 'and', 'the', 'corporal', 'while', 'method', '2', 'does', 'not', 'therefore', 'method', '1', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '2', 'to', 'understand', 'how', 'the', 'captain', 'affects', 'prisoner']
# failed
# 0
# correct_count is  585
# ['method', '1', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '2', 'to', 'understand', 'how', 'appearance', 'affects', 'talent', 'method', '1', 'looks', 'at', 'how', 'appearance', 'correlates', 'with', 'talent', 'case', 'by', 'case', 'according', 'to', 'fame', 'this', 'allows', 'us', 'to', 'see', 'if', 'there', 'is', 'a', 'relationship', 'between', 'appearance', 'and', 'talent', 'that', 'is', 'specific', 'to', 'famous', 'people', 'for', 'example', 'we', 'might', 'find', 'that', 'famous', 'people', 'who', 'are', 'considered', 'to', 'be', 'attractive', 'are', 'also', 'more', 'likely', 'to', 'be', 'talented', 'this', 'would', 'suggest', 'that', 'appearance', 'can', 'help', 'someone', 'become', 'famous', 'even', 'if', 'they', 'do', 'not', 'have', 'a', 'lot', 'of', 'talent', 'method', '2', 'on', 'the', 'other', 'hand', 'looks', 'directly', 'at', 'how', 'appearance', 'correlates', 'with', 'talent', 'in', 'general', 'this', 'does', 'not', 'take', 'into', 'account', 'the', 'role', 'of', 'fame', 'as', 'a', 'result', 'it', 'is', 'more', 'likely', 'to', 'find', 'a', 'correlation', 'between', 'appearance', 'and', 'talent', 'even', 'if', 'this', 'correlation', 'is', 'not', 'due', 'to', 'fame', 'for', 'example', 'we', 'might', 'find', 'that', 'people', 'who', 'are', 'considered', 'to', 'be', 'attractive', 'are', 'also', 'more', 'likely', 'to', 'be', 'talented', 'in', 'general', 'however', 'this', 'does', 'not', 'necessarily', 'mean', 'that', 'appearance', 'helps', 'people', 'become', 'talented', 'it', 'could', 'simply', 'be', 'that', 'people', 'who', 'are', 'attractive', 'are', 'more', 'likely', 'to', 'be', 'given', 'opportunities', 'to', 'develop', 'their', 'talents', 'therefore', 'method', '1', 'is', 'more', 'correct', 'to', 'use', 'than', 'method', '2', 'to', 'understand', 'how', 'appearance', 'affects', 'talent', 'method', '1', 'allows', 'us', 'to', 'see', 'if', 'there', 'is', 'a', 'relationship', 'between', 'appearance', 'and', 'talent', 'that', 'is', 'specific', 'to', 'famous', 'people', 'which', 'is', 'more', 'likely', 'to', 'be', 'due', 'to', 'the', 'role', 'of', 'fame']
# failed
# ['it', 'cannot', 'be', 'determined', 'whether', 'the', 'patient', 'doesn', 't', 'recover', 'if', 'low', 'hospital', 'bill', 'instead', 'of', 'high', 'hospital', 'bill', 'the', 'provided', 'information', 'is', 'insufficient', 'to', 'establish', 'a', 'causal', 'relationship', 'between', 'the', 'patient', 's', 'age', 'hospital', 'costs', 'and', 'recovery']
# failed
# ['the', 'probability', 'of', 'the', 'forest', 'being', 'on', 'fire', 'is', 'higher', 'than', 'the', 'probability', 'of', 'the', 'forest', 'not', 'being', 'on', 'fire', 'let', 'e', 'event', 'that', 'the', 'forest', 'is', 'on', 'fire', 'e', 'event', 'that', 'the', 'forest', 'is', 'not', 'on', 'fire', 's', 'event', 'that', 'a', 'person', 'speaks', 'english', 's', 'event', 'that', 'a', 'person', 'does', 'not', 'speak', 'english', 'we', 'are', 'given', 'p', 's', '0', '93', 'p', 'e', 's', '0', '79', 'p', 'e', 's', '0', '65', 'we', 'want', 'to', 'find', 'p', 'e', 'and', 'p', 'e', 'using', 'the', 'law', 'of', 'total', 'probability', 'p', 'e', 'p', 'e', 's', 'p', 's', 'p', 'e', 's', 'p', 's', 'p', 'e', '0', '65', '0', '93', '0', '79', '0', '07', 'p', 'e', '0', '6045', '0', '0553', 'p', 'e', '0', '6598', 'therefore', 'p', 'e', '1', 'p', 'e', '1', '0', '6598', '0', '3402', 'hence', 'the', 'probability', 'of', 'the', 'forest', 'being', 'on', 'fire', 'is', 'higher', 'than', 'the', 'probability', 'of', 'the', 'forest', 'not', 'being', 'on', 'fire']
# failed
# 1
# correct_count is  586
# ['yes', 'the', 'chance', 'of', 'lung', 'cancer', 'is', 'smaller', 'when', 'observing', 'listening', 'to', 'jazz', 'given', 'p', 'jazz', '0', '19', 'p', 'no', 'jazz', 'and', 'lung', 'cancer', '0', '37', 'p', 'jazz', 'and', 'lung', 'cancer', '0', '10', 'we', 'can', 'use', 'the', 'law', 'of', 'total', 'probability', 'to', 'find', 'the', 'probability', 'of', 'lung', 'cancer', 'p', 'lung', 'cancer', 'p', 'jazz', 'and', 'lung', 'cancer', 'p', 'no', 'jazz', 'and', 'lung', 'cancer', 'p', 'lung', 'cancer', '0', '10', '0', '37', 'p', 'lung', 'cancer', '0', '47', 'now', 'we', 'can', 'find', 'the', 'probability', 'of', 'lung', 'cancer', 'given', 'that', 'someone', 'listens', 'to', 'jazz', 'p', 'lung', 'cancer', 'jazz', 'p', 'jazz', 'and', 'lung', 'cancer', 'p', 'jazz', 'p', 'lung', 'cancer', 'jazz', '0', '10', '0', '19', 'p', 'lung', 'cancer', 'jazz', '0', '526', 'therefore', 'the', 'chance', 'of', 'lung', 'cancer', 'is', 'smaller', 'when', 'observing', 'listening', 'to', 'jazz', 'as', 'the', 'probability', 'of', 'lung', 'cancer', 'given', 'that', 'someone', 'listens', 'to', 'jazz', '0', '526', 'is', 'lower', 'than', 'the', 'overall', 'probability', 'of', 'lung', 'cancer', '0', '47']
# failed
# 1
# correct_count is  587
# 0
# correct_count is  588
# ['yes', 'smoking', 'will', 'increase', 'the', 'chance', 'of', 'lung', 'cancer', 'to', 'calculate', 'the', 'overall', 'probability', 'of', 'lung', 'cancer', 'we', 'can', 'use', 'the', 'law', 'of', 'total', 'probability', 'p', 'lung', 'cancer', 'p', 'lung', 'cancer', 'smoking', 'p', 'smoking', 'p', 'lung', 'cancer', 'nonsmoking', 'p', 'nonsmoking', 'we', 'are', 'given', 'that', 'p', 'smoking', '0', '58', 'and', 'p', 'nonsmoking', '1', 'p', 'smoking', '0', '42', 'to', 'calculate', 'p', 'lung', 'cancer', 'smoking', 'we', 'can', 'use', 'the', 'law', 'of', 'total', 'probability', 'again', 'p', 'lung', 'cancer', 'smoking', 'p', 'lung', 'cancer', 'high', 'tar', 'deposit', 'smoking', 'p', 'high', 'tar', 'deposit', 'smoking', 'p', 'lung', 'cancer', 'no', 'tar', 'deposit', 'smoking', 'p', 'no', 'tar', 'deposit', 'smoking', 'we', 'are', 'given', 'that', 'p', 'high', 'tar', 'deposit', 'smoking', '0', '58', 'and', 'p', 'no', 'tar', 'deposit', 'smoking', '1', 'p', 'high', 'tar', 'deposit', 'smoking', '0', '42', 'we', 'are', 'also', 'given', 'that', 'p', 'lung', 'cancer', 'high', 'tar', 'deposit', 'smoking', '0', '62', 'and', 'p', 'lung', 'cancer', 'no', 'tar', 'deposit', 'smoking', '0', '27', 'therefore', 'p', 'lung', 'cancer', 'smoking', '0', '62', '0', '58', '0', '27', '0', '42', '0', '44', 'to', 'calculate', 'p', 'lung', 'cancer', 'nonsmoking', 'we', 'can', 'use', 'the', 'law', 'of', 'total', 'probability', 'again', 'p', 'lung', 'cancer', 'nonsmoking', 'p', 'lung', 'cancer', 'high', 'tar', 'deposit', 'nonsmoking', 'p', 'high', 'tar', 'deposit', 'nonsmoking', 'p', 'lung', 'cancer', 'no', 'tar', 'deposit', 'nonsmoking', 'p', 'no', 'tar', 'deposit', 'nonsmoking', 'we', 'are', 'given', 'that', 'p', 'high', 'tar', 'deposit', 'nonsmoking', '0', '28', 'and', 'p', 'no', 'tar', 'deposit', 'nonsmoking', '1', 'p', 'high', 'tar', 'deposit', 'nonsmoking', '0', '72', 'we', 'are', 'also', 'given', 'that', 'p', 'lung', 'cancer', 'high', 'tar', 'deposit', 'nonsmoking', '0', '77', 'and', 'p', 'lung', 'cancer', 'no', 'tar', 'deposit', 'nonsmoking', '0', '49', 'therefore', 'p', 'lung', 'cancer', 'nonsmoking', '0', '77', '0', '28', '0', '49', '0', '72', '0', '58', 'finally', 'we', 'can', 'calculate', 'the', 'overall', 'probability', 'of', 'lung', 'cancer', 'p', 'lung', 'cancer', '0', '44', '0', '58', '0', '58', '0', '42', '0', '51', 'therefore', 'the', 'overall', 'probability', 'of', 'lung', 'cancer', 'is', '51', 'which', 'is', 'higher', 'than', 'the', 'probability', 'of', 'lung', 'cancer', 'for', 'nonsmokers', '49', 'and', 'lower', 'than', 'the', 'probability', 'of', 'lung', 'cancer', 'for', 'smokers', '62', 'this', 'indicates', 'that', 'smoking', 'increases', 'the', 'chance', 'of', 'lung', 'cancer']
# failed
# 1
# correct_count is  589
# correct_count in wrapper is  589
# Accuracy: 5.82%

# %%
with open("y_true.txt", "w") as f:
    for s in y_true:
        f.write(str(s) +"\n")

# %%
with open("y_pred.txt", "w") as f:
    for s in y_pred:
        f.write(str(s) +"\n")

# %%
with open("processed.txt", "w") as f:
    for s in processed:
        f.write(str(s) +"\n")

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.41      0.50       496
#            1       0.57      0.76      0.65       504
#
#     accuracy                           0.59      1000
#    macro avg       0.60      0.59      0.58      1000
# weighted avg       0.60      0.59      0.58      1000
